# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
# Comment out appropriate portion
#tk = th.Thicket.from_caliperreader(glob("cali_files/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/Random/Strong_Scaling_MPI/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/MPI_Files/65536_Weak_Test/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/MPI_Files/16777216_Strong/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/CUDA_Files/65536_Strong_Compare/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/CUDA_Files/65536_Weak/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/CUDA_Files/65536_Strong/*.cali"))

# tk = th.Thicket.from_caliperreader(glob("cali_files/Aazmir/CUDA/Strong/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/Aazmir/CUDA/Weak/*.cali"))

# tk = th.Thicket.from_caliperreader(glob("cali_files/CUDA_Files/262144/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/CUDA_Files/1048576/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/CUDA_Files/4194304/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/CUDA_Files/16777216/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/CUDA_Files/67108864/*.cali"))

# %%
# Performance data
tk.dataframe
#CUDA
tk.dataframe = tk.dataframe.drop([('Min time/rank'),('Max time/rank'),('Total time'),("Avg time/rank"),("Min GPU time/rank"),("Max GPU time/rank"),("Total GPU time"), ('nid')], axis=1)
# tk.dataframe = tk.dataframe.drop([('Min time/rank'),('Max time/rank'),('Total time'),("Avg time/rank"), ('nid')], axis=1)

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 134839465            2.11.0-dev
# 289351847            2.11.0-dev
# 310786328            2.11.0-dev
# 326337763            2.11.0-dev
# 432672454            2.11.0-dev
# 563747709            2.11.0-dev
# 769362115            2.11.0-dev
# 774993442            2.11.0-dev
# 1156622377           2.11.0-dev
# 1555078326           2.11.0-dev
# 1781503066           2.11.0-dev
# 2201939640           2.11.0-dev
# 2475280408           2.11.0-dev
# 2493596621           2.11.0-dev
# 3270180596           2.11.0-dev
# 3405790495           2.11.0-dev
# 3700513011           2.11.0-dev
# 3917455969           2.11.0-dev
# 3961089413           2.11.0-dev
# 4244402952           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 134839465   min#inclusive#sum#time.duration,max#inclusive#...
# 289351847   min#inclusive#sum#time.duration,max#inclusive#...
# 310786328   min#inclusive#sum#time.duration,max#inclusive#...
# ...

# %%
tk.metadata
tk.statsframe.dataframe["time"] = 1
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  └─ 1.000 comm_large
# │     └─ 1.000 cudaMemcpy
# ├─ 1.000 comp
# │  └─ 1.000 comp_large
# ├─ 1.000 correctness_check
# └─ 1.000 date_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
# strong
# gb = tk.groupby([("InputSize"), ("Algorithm")])
gb = tk.groupby([("InputSize"), ("InputType")])
# weak
# gb = tk.groupby([("InputType")])
# Out:
# 4  thickets created...
# {(67108864, '1%Perturbed'): <thicket.thicket.Thicket object at 0x2b9f22708760>, (67108864, 'Random'): <thicket.thicket.Thicket object at 0x2b9f224cec70>, (67108864, 'ReverseSorted'): <thicket.thicket.Thicket object at 0x2b9f225d77f0>, (67108864, 'Sorted'): <thicket.thicket.Thicket object at 0x2b9f1fef8580>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_threads"
)

# %%
ctk.dataframe
# Out:
#                                                               (67108864, 1%Perturbed)  \
#                                                                          spot.channel
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                    regionprofile
#                                                   128                   regionprofile
#                                                   256                   regionprofile
#                                                   512                   regionprofile
#                                                   1024                  regionprofile
# {'name': 'comm', 'type': 'function'}              64                    regionprofile
#                                                   128                   regionprofile
#                                                   256                   regionprofile
# ...

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", "")], axis=1)
# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

# %% [raw]
# ctk.dataframe

# %%
# Define common variables
function_names = set(ctk.dataframe.index.get_level_values("name"))
procs = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
matrix_sizes = sorted(ctk.dataframe.columns.tolist())

# %%
ctk.dataframe.loc["main"]
# Out:
#             (67108864, 1%Perturbed)                   (67108864, Random)  \
#                        spot.channel Avg GPU time/rank       spot.channel
# num_threads
# 64                    regionprofile         24.679872      regionprofile
# 128                   regionprofile         24.666659      regionprofile
# 256                   regionprofile         24.826219      regionprofile
# 512                   regionprofile         24.954450      regionprofile
# 1024                  regionprofile         25.124479      regionprofile
#
#                               (67108864, ReverseSorted)                    \
#             Avg GPU time/rank              spot.channel Avg GPU time/rank
# num_threads
# 64                  25.708550             regionprofile         17.122432
# 128                 25.814919             regionprofile         17.235990
# 256                 25.864269             regionprofile         17.352387
# ...

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %%
for name in function_names:
    plot_pandas(
        df=ctk.dataframe.loc[name],
        title="Merge Sort | Strong Scaling | CUDA | 67108864 | " + name,
        xlabel="Number of Threads",
        ylabel="Time (seconds)",
        # set to False 
        loglog=False
    )

# %%
# how to get input_sizes?
# speed up
input_sizes = set(tk.metadata["InputSize"])
for name in function_names:
    for size in input_sizes:
        temp_df = ctk.dataframe[[col for col in ctk.dataframe.columns if col[0][0] == 67108864 and col[1] == "Avg GPU time/rank"]].loc[name]
        temp_df = temp_df.iloc[0]/temp_df

        plot_pandas (
            title = "Speed Up | CUDA | 67108864 | " + name,
            xlabel = "Threads",
            ylabel = "Time (seconds)",
            # True or False? 
            loglog=False,
            df = temp_df
        )
