# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
# Comment out appropriate portion
#tk = th.Thicket.from_caliperreader(glob("cali_files/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/Random/Strong_Scaling_MPI/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/MPI_Files/Weak_Test/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/MPI_Files/65536_Strong/*.cali"))

# tk = th.Thicket.from_caliperreader(glob("cali_files/MPI_Files/65536_Strong_Compare/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/Aazmir/MPI/Weak/*.cali"))

# tk = th.Thicket.from_caliperreader(glob("cali_files/MPI_Files/262144/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/MPI_Files/1048576/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/MPI_Files/4194304/*.cali"))
tk = th.Thicket.from_caliperreader(glob("cali_files/MPI_Files/16777216/*.cali"))

# %%
# Performance data
tk.dataframe
#MPI
tk.dataframe = tk.dataframe.drop([('Min time/rank'),('Max time/rank'),('Total time'), ('Variance time/rank'), ('nid')], axis=1)

# %%
GET /cali_files/MPI_Files/16777216
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-91fb37f9e2cc> in <module>
# ----> 1 GET /cali_files/MPI_Files/16777216
#
# NameError: name 'GET' is not defined

# %%
tk.metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 200708868            2.11.0-dev             128
# 231973805            2.11.0-dev               8
# 353431450            2.11.0-dev              32
# 368457904            2.11.0-dev              32
# 453776784            2.11.0-dev               2
# 645801691            2.11.0-dev               2
# 832377432            2.11.0-dev               2
# 1015332189           2.11.0-dev              16
# 1020902034           2.11.0-dev               8
# 1154851741           2.11.0-dev              64
# 1187448243           2.11.0-dev            1024
# 1189469416           2.11.0-dev             256
# 1222860430           2.11.0-dev              64
# 1345645215           2.11.0-dev            1024
# 1432610729           2.11.0-dev              64
# 1475728221           2.11.0-dev             128
# 1645138699           2.11.0-dev               4
# 1689145327           2.11.0-dev               4
# 1718238397           2.11.0-dev             512
# 1919672588           2.11.0-dev             512
# 1973453532           2.11.0-dev              64
# 2108410928           2.11.0-dev               4
# 2140081730           2.11.0-dev             128
# 2220374503           2.11.0-dev               4
# 2351926979           2.11.0-dev             256
# 2452817692           2.11.0-dev            1024
# 2784422760           2.11.0-dev              16
# 2978936505           2.11.0-dev               2
# 3026937827           2.11.0-dev              32
# 3122454997           2.11.0-dev             128
# 3286916717           2.11.0-dev               8
# 3321109239           2.11.0-dev              32
# 3342173298           2.11.0-dev               8
# 3372913031           2.11.0-dev             256
# 3429932930           2.11.0-dev             512
# 3432677075           2.11.0-dev              16
# 3697775432           2.11.0-dev            1024
# 4008270369           2.11.0-dev             256
# 4013398744           2.11.0-dev              16
# 4283455612           2.11.0-dev             512
#
#                                                  spot.metrics  \
# profile
# 200708868   min#inclusive#sum#time.duration,max#inclusive#...
# 231973805   min#inclusive#sum#time.duration,max#inclusive#...
# 353431450   min#inclusive#sum#time.duration,max#inclusive#...
# 368457904   min#inclusive#sum#time.duration,max#inclusive#...
# 453776784   min#inclusive#sum#time.duration,max#inclusive#...
# 645801691   min#inclusive#sum#time.duration,max#inclusive#...
# 832377432   min#inclusive#sum#time.duration,max#inclusive#...
# 1015332189  min#inclusive#sum#time.duration,max#inclusive#...
# 1020902034  min#inclusive#sum#time.duration,max#inclusive#...
# 1154851741  min#inclusive#sum#time.duration,max#inclusive#...
# 1187448243  min#inclusive#sum#time.duration,max#inclusive#...
# 1189469416  min#inclusive#sum#time.duration,max#inclusive#...
# 1222860430  min#inclusive#sum#time.duration,max#inclusive#...
# 1345645215  min#inclusive#sum#time.duration,max#inclusive#...
# 1432610729  min#inclusive#sum#time.duration,max#inclusive#...
# 1475728221  min#inclusive#sum#time.duration,max#inclusive#...
# 1645138699  min#inclusive#sum#time.duration,max#inclusive#...
# 1689145327  min#inclusive#sum#time.duration,max#inclusive#...
# 1718238397  min#inclusive#sum#time.duration,max#inclusive#...
# 1919672588  min#inclusive#sum#time.duration,max#inclusive#...
# 1973453532  min#inclusive#sum#time.duration,max#inclusive#...
# 2108410928  min#inclusive#sum#time.duration,max#inclusive#...
# 2140081730  min#inclusive#sum#time.duration,max#inclusive#...
# 2220374503  min#inclusive#sum#time.duration,max#inclusive#...
# 2351926979  min#inclusive#sum#time.duration,max#inclusive#...
# 2452817692  min#inclusive#sum#time.duration,max#inclusive#...
# 2784422760  min#inclusive#sum#time.duration,max#inclusive#...
# 2978936505  min#inclusive#sum#time.duration,max#inclusive#...
# 3026937827  min#inclusive#sum#time.duration,max#inclusive#...
# 3122454997  min#inclusive#sum#time.duration,max#inclusive#...
# 3286916717  min#inclusive#sum#time.duration,max#inclusive#...
# 3321109239  min#inclusive#sum#time.duration,max#inclusive#...
# 3342173298  min#inclusive#sum#time.duration,max#inclusive#...
# 3372913031  min#inclusive#sum#time.duration,max#inclusive#...
# 3429932930  min#inclusive#sum#time.duration,max#inclusive#...
# 3432677075  min#inclusive#sum#time.duration,max#inclusive#...
# 3697775432  min#inclusive#sum#time.duration,max#inclusive#...
# 4008270369  min#inclusive#sum#time.duration,max#inclusive#...
# 4013398744  min#inclusive#sum#time.duration,max#inclusive#...
# 4283455612  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 200708868                                             2
# 231973805                                             2
# 353431450                                             2
# 368457904                                             2
# 453776784                                             2
# 645801691                                             2
# 832377432                                             2
# 1015332189                                            2
# 1020902034                                            2
# 1154851741                                            2
# 1187448243                                            2
# 1189469416                                            2
# 1222860430                                            2
# 1345645215                                            2
# 1432610729                                            2
# 1475728221                                            2
# 1645138699                                            2
# 1689145327                                            2
# 1718238397                                            2
# 1919672588                                            2
# 1973453532                                            2
# 2108410928                                            2
# 2140081730                                            2
# 2220374503                                            2
# 2351926979                                            2
# 2452817692                                            2
# 2784422760                                            2
# 2978936505                                            2
# 3026937827                                            2
# 3122454997                                            2
# 3286916717                                            2
# 3321109239                                            2
# 3342173298                                            2
# 3372913031                                            2
# 3429932930                                            2
# 3432677075                                            2
# 3697775432                                            2
# 4008270369                                            2
# 4013398744                                            2
# 4283455612                                            2
#
#                         spot.options  spot.channels cali.channel  \
# profile
# 200708868   time.variance,node.order  regionprofile         spot
# 231973805   time.variance,node.order  regionprofile         spot
# 353431450   time.variance,node.order  regionprofile         spot
# 368457904   time.variance,node.order  regionprofile         spot
# 453776784   time.variance,node.order  regionprofile         spot
# 645801691   time.variance,node.order  regionprofile         spot
# 832377432   time.variance,node.order  regionprofile         spot
# 1015332189  time.variance,node.order  regionprofile         spot
# 1020902034  time.variance,node.order  regionprofile         spot
# 1154851741  time.variance,node.order  regionprofile         spot
# 1187448243  time.variance,node.order  regionprofile         spot
# 1189469416  time.variance,node.order  regionprofile         spot
# 1222860430  time.variance,node.order  regionprofile         spot
# 1345645215  time.variance,node.order  regionprofile         spot
# 1432610729  time.variance,node.order  regionprofile         spot
# 1475728221  time.variance,node.order  regionprofile         spot
# 1645138699  time.variance,node.order  regionprofile         spot
# 1689145327  time.variance,node.order  regionprofile         spot
# 1718238397  time.variance,node.order  regionprofile         spot
# 1919672588  time.variance,node.order  regionprofile         spot
# 1973453532  time.variance,node.order  regionprofile         spot
# 2108410928  time.variance,node.order  regionprofile         spot
# 2140081730  time.variance,node.order  regionprofile         spot
# 2220374503  time.variance,node.order  regionprofile         spot
# 2351926979  time.variance,node.order  regionprofile         spot
# 2452817692  time.variance,node.order  regionprofile         spot
# 2784422760  time.variance,node.order  regionprofile         spot
# 2978936505  time.variance,node.order  regionprofile         spot
# 3026937827  time.variance,node.order  regionprofile         spot
# 3122454997  time.variance,node.order  regionprofile         spot
# 3286916717  time.variance,node.order  regionprofile         spot
# 3321109239  time.variance,node.order  regionprofile         spot
# 3342173298  time.variance,node.order  regionprofile         spot
# 3372913031  time.variance,node.order  regionprofile         spot
# 3429932930  time.variance,node.order  regionprofile         spot
# 3432677075  time.variance,node.order  regionprofile         spot
# 3697775432  time.variance,node.order  regionprofile         spot
# 4008270369  time.variance,node.order  regionprofile         spot
# 4013398744  time.variance,node.order  regionprofile         spot
# 4283455612  time.variance,node.order  regionprofile         spot
#
#            spot:node.order           spot:output spot:time.variance  \
# profile
# 200708868             true   p128-a16777216.cali               true
# 231973805             true     p8-a16777216.cali               true
# 353431450             true    p32-a16777216.cali               true
# 368457904             true    p32-a16777216.cali               true
# 453776784             true     p2-a16777216.cali               true
# 645801691             true     p2-a16777216.cali               true
# 832377432             true     p2-a16777216.cali               true
# 1015332189            true    p16-a16777216.cali               true
# 1020902034            true     p8-a16777216.cali               true
# 1154851741            true    p64-a16777216.cali               true
# 1187448243            true  p1024-a16777216.cali               true
# 1189469416            true   p256-a16777216.cali               true
# 1222860430            true    p64-a16777216.cali               true
# 1345645215            true  p1024-a16777216.cali               true
# 1432610729            true    p64-a16777216.cali               true
# 1475728221            true   p128-a16777216.cali               true
# 1645138699            true     p4-a16777216.cali               true
# 1689145327            true     p4-a16777216.cali               true
# 1718238397            true   p512-a16777216.cali               true
# 1919672588            true   p512-a16777216.cali               true
# 1973453532            true    p64-a16777216.cali               true
# 2108410928            true     p4-a16777216.cali               true
# 2140081730            true   p128-a16777216.cali               true
# 2220374503            true     p4-a16777216.cali               true
# 2351926979            true   p256-a16777216.cali               true
# 2452817692            true  p1024-a16777216.cali               true
# 2784422760            true    p16-a16777216.cali               true
# 2978936505            true     p2-a16777216.cali               true
# 3026937827            true    p32-a16777216.cali               true
# 3122454997            true   p128-a16777216.cali               true
# 3286916717            true     p8-a16777216.cali               true
# 3321109239            true    p32-a16777216.cali               true
# 3342173298            true     p8-a16777216.cali               true
# 3372913031            true   p256-a16777216.cali               true
# 3429932930            true   p512-a16777216.cali               true
# 3432677075            true    p16-a16777216.cali               true
# 3697775432            true  p1024-a16777216.cali               true
# 4008270369            true   p256-a16777216.cali               true
# 4013398744            true    p16-a16777216.cali               true
# 4283455612            true   p512-a16777216.cali               true
#
#             launchdate                                          libraries  \
# profile
# 200708868   1701904689  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 231973805   1701881549  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 353431450   1701882312  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 368457904   1701882736  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 453776784   1701904123  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 645801691   1701882736  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 832377432   1701882294  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1015332189  1701904141  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1020902034  1701882307  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1154851741  1701904642  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1187448243  1701882608  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1189469416  1701883052  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1222860430  1701881712  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1345645215  1701906583  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1432610729  1701882412  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1475728221  1701882452  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1645138699  1701904123  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1689145327  1701882736  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1718238397  1701904820  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1919672588  1701883073  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1973453532  1701882966  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2108410928  1701882294  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2140081730  1701883027  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2220374503  1701881549  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2351926979  1701882512  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2452817692  1701883334  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2784422760  1701881549  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2978936505  1701881549  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3026937827  1701904141  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3122454997  1701881852  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3286916717  1701882736  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3321109239  1701881549  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3342173298  1701904123  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3372913031  1701904741  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3429932930  1701882573  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3432677075  1701882736  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3697775432  1701882126  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4008270369  1701881944  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4013398744  1701882307  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4283455612  1701882012  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                             cmdline cluster  Algorithm ProgrammingModel  \
# profile
# 200708868   [./mergesort, 16777216]       c  MergeSort              MPI
# 231973805   [./mergesort, 16777216]       c  MergeSort              MPI
# 353431450   [./mergesort, 16777216]       c  MergeSort              MPI
# 368457904   [./mergesort, 16777216]       c  MergeSort              MPI
# 453776784   [./mergesort, 16777216]       c  MergeSort              MPI
# 645801691   [./mergesort, 16777216]       c  MergeSort              MPI
# 832377432   [./mergesort, 16777216]       c  MergeSort              MPI
# 1015332189  [./mergesort, 16777216]       c  MergeSort              MPI
# 1020902034  [./mergesort, 16777216]       c  MergeSort              MPI
# 1154851741  [./mergesort, 16777216]       c  MergeSort              MPI
# 1187448243  [./mergesort, 16777216]       c  MergeSort              MPI
# 1189469416  [./mergesort, 16777216]       c  MergeSort              MPI
# 1222860430  [./mergesort, 16777216]       c  MergeSort              MPI
# 1345645215  [./mergesort, 16777216]       c  MergeSort              MPI
# 1432610729  [./mergesort, 16777216]       c  MergeSort              MPI
# 1475728221  [./mergesort, 16777216]       c  MergeSort              MPI
# 1645138699  [./mergesort, 16777216]       c  MergeSort              MPI
# 1689145327  [./mergesort, 16777216]       c  MergeSort              MPI
# 1718238397  [./mergesort, 16777216]       c  MergeSort              MPI
# 1919672588  [./mergesort, 16777216]       c  MergeSort              MPI
# 1973453532  [./mergesort, 16777216]       c  MergeSort              MPI
# 2108410928  [./mergesort, 16777216]       c  MergeSort              MPI
# 2140081730  [./mergesort, 16777216]       c  MergeSort              MPI
# 2220374503  [./mergesort, 16777216]       c  MergeSort              MPI
# 2351926979  [./mergesort, 16777216]       c  MergeSort              MPI
# 2452817692  [./mergesort, 16777216]       c  MergeSort              MPI
# 2784422760  [./mergesort, 16777216]       c  MergeSort              MPI
# 2978936505  [./mergesort, 16777216]       c  MergeSort              MPI
# 3026937827  [./mergesort, 16777216]       c  MergeSort              MPI
# 3122454997  [./mergesort, 16777216]       c  MergeSort              MPI
# 3286916717  [./mergesort, 16777216]       c  MergeSort              MPI
# 3321109239  [./mergesort, 16777216]       c  MergeSort              MPI
# 3342173298  [./mergesort, 16777216]       c  MergeSort              MPI
# 3372913031  [./mergesort, 16777216]       c  MergeSort              MPI
# 3429932930  [./mergesort, 16777216]       c  MergeSort              MPI
# 3432677075  [./mergesort, 16777216]       c  MergeSort              MPI
# 3697775432  [./mergesort, 16777216]       c  MergeSort              MPI
# 4008270369  [./mergesort, 16777216]       c  MergeSort              MPI
# 4013398744  [./mergesort, 16777216]       c  MergeSort              MPI
# 4283455612  [./mergesort, 16777216]       c  MergeSort              MPI
#
#            Datatype  SizeOfDatatype  InputSize      InputType  num_procs  \
# profile
# 200708868     float               4   16777216    1%Perturbed        128
# 231973805     float               4   16777216         Random          8
# 353431450     float               4   16777216         Sorted         32
# 368457904     float               4   16777216  ReverseSorted         32
# 453776784     float               4   16777216    1%Perturbed          2
# 645801691     float               4   16777216  ReverseSorted          2
# 832377432     float               4   16777216         Sorted          2
# 1015332189    float               4   16777216    1%Perturbed         16
# 1020902034    float               4   16777216         Sorted          8
# 1154851741    float               4   16777216    1%Perturbed         64
# 1187448243    float               4   16777216         Sorted       1024
# 1189469416    float               4   16777216  ReverseSorted        256
# 1222860430    float               4   16777216         Random         64
# 1345645215    float               4   16777216    1%Perturbed       1024
# 1432610729    float               4   16777216         Sorted         64
# 1475728221    float               4   16777216         Sorted        128
# 1645138699    float               4   16777216    1%Perturbed          4
# 1689145327    float               4   16777216  ReverseSorted          4
# 1718238397    float               4   16777216    1%Perturbed        512
# 1919672588    float               4   16777216  ReverseSorted        512
# 1973453532    float               4   16777216  ReverseSorted         64
# 2108410928    float               4   16777216         Sorted          4
# 2140081730    float               4   16777216  ReverseSorted        128
# 2220374503    float               4   16777216         Random          4
# 2351926979    float               4   16777216         Sorted        256
# 2452817692    float               4   16777216  ReverseSorted       1024
# 2784422760    float               4   16777216         Random         16
# 2978936505    float               4   16777216         Random          2
# 3026937827    float               4   16777216    1%Perturbed         32
# 3122454997    float               4   16777216         Random        128
# 3286916717    float               4   16777216  ReverseSorted          8
# 3321109239    float               4   16777216         Random         32
# 3342173298    float               4   16777216    1%Perturbed          8
# 3372913031    float               4   16777216    1%Perturbed        256
# 3429932930    float               4   16777216         Sorted        512
# 3432677075    float               4   16777216  ReverseSorted         16
# 3697775432    float               4   16777216         Random       1024
# 4008270369    float               4   16777216         Random        256
# 4013398744    float               4   16777216         Sorted         16
# 4283455612    float               4   16777216         Random        512
#
#             num_threads  num_blocks  group_num implementation_source
# profile
# 200708868             0           0         24      AI / Handwritten
# 231973805             0           0         24      AI / Handwritten
# 353431450             0           0         24      AI / Handwritten
# 368457904             0           0         24      AI / Handwritten
# 453776784             0           0         24      AI / Handwritten
# 645801691             0           0         24      AI / Handwritten
# 832377432             0           0         24      AI / Handwritten
# 1015332189            0           0         24      AI / Handwritten
# 1020902034            0           0         24      AI / Handwritten
# 1154851741            0           0         24      AI / Handwritten
# 1187448243            0           0         24      AI / Handwritten
# 1189469416            0           0         24      AI / Handwritten
# 1222860430            0           0         24      AI / Handwritten
# 1345645215            0           0         24      AI / Handwritten
# 1432610729            0           0         24      AI / Handwritten
# 1475728221            0           0         24      AI / Handwritten
# 1645138699            0           0         24      AI / Handwritten
# 1689145327            0           0         24      AI / Handwritten
# 1718238397            0           0         24      AI / Handwritten
# 1919672588            0           0         24      AI / Handwritten
# 1973453532            0           0         24      AI / Handwritten
# 2108410928            0           0         24      AI / Handwritten
# 2140081730            0           0         24      AI / Handwritten
# 2220374503            0           0         24      AI / Handwritten
# 2351926979            0           0         24      AI / Handwritten
# 2452817692            0           0         24      AI / Handwritten
# 2784422760            0           0         24      AI / Handwritten
# 2978936505            0           0         24      AI / Handwritten
# 3026937827            0           0         24      AI / Handwritten
# 3122454997            0           0         24      AI / Handwritten
# 3286916717            0           0         24      AI / Handwritten
# 3321109239            0           0         24      AI / Handwritten
# 3342173298            0           0         24      AI / Handwritten
# 3372913031            0           0         24      AI / Handwritten
# 3429932930            0           0         24      AI / Handwritten
# 3432677075            0           0         24      AI / Handwritten
# 3697775432            0           0         24      AI / Handwritten
# 4008270369            0           0         24      AI / Handwritten
# 4013398744            0           0         24      AI / Handwritten
# 4283455612            0           0         24      AI / Handwritten

# %%
tk.metadata
tk.statsframe.dataframe["time"] = 1
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  ├─ 1.000 comm_large
# │  │  ├─ 1.000 MPI_Bcast
# │  │  └─ 1.000 MPI_Scatter
# │  └─ 1.000 comm_small
# │     ├─ 1.000 MPI_Recv
# │     └─ 1.000 MPI_Send
# ├─ 1.000 comp
# │  └─ 1.000 comp_large
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
# strong
# gb = tk.groupby([("InputSize"),("Algorithm")])
gb = tk.groupby([("InputSize"), ("InputType")])
# weak
# gb = tk.groupby([("InputType")])
# Out:
# 4  thickets created...
# {(16777216, '1%Perturbed'): <thicket.thicket.Thicket object at 0x2b8c16056100>, (16777216, 'Random'): <thicket.thicket.Thicket object at 0x2b8c0ff5b2e0>, (16777216, 'ReverseSorted'): <thicket.thicket.Thicket object at 0x2b8c167f9d90>, (16777216, 'Sorted'): <thicket.thicket.Thicket object at 0x2b8c0fc72eb0>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    #MPI
    metadata_key="num_procs"
)

# %%
ctk.dataframe
# Out:
#                                                             (16777216, 1%Perturbed)  \
#                                                                        spot.channel
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2                   regionprofile
#                                                   4                   regionprofile
#                                                   8                   regionprofile
#                                                   16                  regionprofile
#                                                   32                  regionprofile
#                                                   64                  regionprofile
#                                                   128                 regionprofile
#                                                   256                 regionprofile
#                                                   512                 regionprofile
#                                                   1024                regionprofile
# {'name': 'comm', 'type': 'function'}              2                   regionprofile
#                                                   4                   regionprofile
#                                                   8                   regionprofile
#                                                   16                  regionprofile
#                                                   32                  regionprofile
#                                                   64                  regionprofile
#                                                   128                 regionprofile
#                                                   256                 regionprofile
#                                                   512                 regionprofile
#                                                   1024                regionprofile
# {'name': 'comm_large', 'type': 'function'}        2                   regionprofile
#                                                   4                   regionprofile
#                                                   8                   regionprofile
#                                                   16                  regionprofile
#                                                   32                  regionprofile
#                                                   64                  regionprofile
#                                                   128                 regionprofile
#                                                   256                 regionprofile
#                                                   512                 regionprofile
#                                                   1024                regionprofile
# {'name': 'MPI_Bcast', 'type': 'function'}         2                   regionprofile
#                                                   4                   regionprofile
#                                                   8                   regionprofile
#                                                   16                  regionprofile
#                                                   32                  regionprofile
#                                                   64                  regionprofile
#                                                   128                 regionprofile
#                                                   256                 regionprofile
#                                                   512                 regionprofile
#                                                   1024                regionprofile
# {'name': 'MPI_Scatter', 'type': 'function'}       2                   regionprofile
#                                                   4                   regionprofile
#                                                   8                   regionprofile
#                                                   16                  regionprofile
#                                                   32                  regionprofile
#                                                   64                  regionprofile
#                                                   128                 regionprofile
#                                                   256                 regionprofile
#                                                   512                 regionprofile
#                                                   1024                regionprofile
# {'name': 'comm_small', 'type': 'function'}        2                   regionprofile
#                                                   4                   regionprofile
#                                                   8                   regionprofile
#                                                   16                  regionprofile
#                                                   32                  regionprofile
#                                                   64                  regionprofile
#                                                   128                 regionprofile
#                                                   256                 regionprofile
#                                                   512                 regionprofile
#                                                   1024                regionprofile
# {'name': 'MPI_Recv', 'type': 'function'}          2                   regionprofile
#                                                   4                   regionprofile
#                                                   8                   regionprofile
#                                                   16                  regionprofile
#                                                   32                  regionprofile
#                                                   64                  regionprofile
#                                                   128                 regionprofile
#                                                   256                 regionprofile
#                                                   512                 regionprofile
#                                                   1024                regionprofile
# {'name': 'MPI_Send', 'type': 'function'}          2                   regionprofile
#                                                   4                   regionprofile
#                                                   8                   regionprofile
#                                                   16                  regionprofile
#                                                   32                  regionprofile
#                                                   64                  regionprofile
#                                                   128                 regionprofile
#                                                   256                 regionprofile
#                                                   512                 regionprofile
#                                                   1024                regionprofile
# {'name': 'comp', 'type': 'function'}              2                   regionprofile
#                                                   4                   regionprofile
#                                                   8                   regionprofile
#                                                   16                  regionprofile
#                                                   32                  regionprofile
#                                                   64                  regionprofile
#                                                   128                 regionprofile
#                                                   256                 regionprofile
#                                                   512                 regionprofile
#                                                   1024                regionprofile
# {'name': 'comp_large', 'type': 'function'}        2                   regionprofile
#                                                   4                   regionprofile
#                                                   8                   regionprofile
#                                                   16                  regionprofile
#                                                   32                  regionprofile
#                                                   64                  regionprofile
#                                                   128                 regionprofile
#                                                   256                 regionprofile
#                                                   512                 regionprofile
#                                                   1024                regionprofile
# {'name': 'correctness_check', 'type': 'function'} 2                   regionprofile
#                                                   4                   regionprofile
#                                                   8                   regionprofile
#                                                   16                  regionprofile
#                                                   32                  regionprofile
#                                                   64                  regionprofile
#                                                   128                 regionprofile
#                                                   256                 regionprofile
#                                                   512                 regionprofile
#                                                   1024                regionprofile
# {'name': 'data_init', 'type': 'function'}         2                   regionprofile
#                                                   4                   regionprofile
#                                                   8                   regionprofile
#                                                   16                  regionprofile
#                                                   32                  regionprofile
#                                                   64                  regionprofile
#                                                   128                 regionprofile
#                                                   256                 regionprofile
#                                                   512                 regionprofile
#                                                   1024                regionprofile
#
#                                                                            \
#                                                             Avg time/rank
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2              2.777662
#                                                   4              1.553406
#                                                   8              1.142955
#                                                   16             1.095480
#                                                   32             1.564576
#                                                   64             1.483067
#                                                   128            1.602832
#                                                   256            1.883084
#                                                   512            2.229880
#                                                   1024           3.190151
# {'name': 'comm', 'type': 'function'}              2              0.076572
#                                                   4              0.100289
#                                                   8              0.108765
#                                                   16             0.097885
#                                                   32             0.104401
#                                                   64             0.096709
#                                                   128            0.099827
#                                                   256            0.133558
#                                                   512            0.148412
#                                                   1024           0.093900
# {'name': 'comm_large', 'type': 'function'}        2              0.064043
#                                                   4              0.081756
#                                                   8              0.092812
#                                                   16             0.088485
#                                                   32             0.097975
#                                                   64             0.092574
#                                                   128            0.097123
#                                                   256            0.131814
#                                                   512            0.147404
#                                                   1024           0.092044
# {'name': 'MPI_Bcast', 'type': 'function'}         2              0.040456
#                                                   4              0.062504
#                                                   8              0.074945
#                                                   16             0.076206
#                                                   32             0.087503
#                                                   64             0.077553
#                                                   128            0.076835
#                                                   256            0.109978
#                                                   512            0.121838
#                                                   1024           0.088233
# {'name': 'MPI_Scatter', 'type': 'function'}       2              0.023538
#                                                   4              0.019215
#                                                   8              0.017829
#                                                   16             0.012243
#                                                   32             0.010432
#                                                   64             0.014991
#                                                   128            0.020253
#                                                   256            0.021801
#                                                   512            0.025532
#                                                   1024           0.003781
# {'name': 'comm_small', 'type': 'function'}        2              0.012483
#                                                   4              0.018474
#                                                   8              0.015893
#                                                   16             0.009340
#                                                   32             0.006365
#                                                   64             0.004077
#                                                   128            0.002644
#                                                   256            0.001685
#                                                   512            0.000951
#                                                   1024           0.001791
# {'name': 'MPI_Recv', 'type': 'function'}          2              0.013832
#                                                   4              0.019290
#                                                   8              0.018988
#                                                   16             0.010881
#                                                   32             0.007841
#                                                   64             0.005119
#                                                   128            0.003541
#                                                   256            0.002277
#                                                   512            0.001324
#                                                   1024           0.002062
# {'name': 'MPI_Send', 'type': 'function'}          2              0.011079
#                                                   4              0.011733
#                                                   8              0.007274
#                                                   16             0.004126
#                                                   32             0.002492
#                                                   64             0.001513
#                                                   128            0.000856
#                                                   256            0.000527
#                                                   512            0.000270
#                                                   1024           0.000741
# {'name': 'comp', 'type': 'function'}              2              2.144752
#                                                   4              1.064753
#                                                   8              0.532041
#                                                   16             0.263373
#                                                   32             0.130262
#                                                   64             0.064474
#                                                   128            0.031992
#                                                   256            0.016145
#                                                   512            0.008245
#                                                   1024           0.004053
# {'name': 'comp_large', 'type': 'function'}        2              2.144689
#                                                   4              1.064707
#                                                   8              0.531999
#                                                   16             0.263336
#                                                   32             0.130227
#                                                   64             0.064440
#                                                   128            0.031962
#                                                   256            0.016118
#                                                   512            0.008220
#                                                   1024           0.004033
# {'name': 'correctness_check', 'type': 'function'} 2              0.043823
#                                                   4              0.043842
#                                                   8              0.043964
#                                                   16             0.044014
#                                                   32             0.044002
#                                                   64             0.043965
#                                                   128            0.044038
#                                                   256            0.044314
#                                                   512            0.044122
#                                                   1024           0.043908
# {'name': 'data_init', 'type': 'function'}         2              0.079486
#                                                   4              0.080310
#                                                   8              0.085892
#                                                   16             0.079770
#                                                   32             0.088568
#                                                   64             0.080500
#                                                   128            0.080521
#                                                   256            0.085561
#                                                   512            0.080208
#                                                   1024           0.080144
#
#                                                             (16777216, Random)  \
#                                                                   spot.channel
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2              regionprofile
#                                                   4              regionprofile
#                                                   8              regionprofile
#                                                   16             regionprofile
#                                                   32             regionprofile
#                                                   64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'comm', 'type': 'function'}              2              regionprofile
#                                                   4              regionprofile
#                                                   8              regionprofile
#                                                   16             regionprofile
#                                                   32             regionprofile
#                                                   64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'comm_large', 'type': 'function'}        2              regionprofile
#                                                   4              regionprofile
#                                                   8              regionprofile
#                                                   16             regionprofile
#                                                   32             regionprofile
#                                                   64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'MPI_Bcast', 'type': 'function'}         2              regionprofile
#                                                   4              regionprofile
#                                                   8              regionprofile
#                                                   16             regionprofile
#                                                   32             regionprofile
#                                                   64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'MPI_Scatter', 'type': 'function'}       2              regionprofile
#                                                   4              regionprofile
#                                                   8              regionprofile
#                                                   16             regionprofile
#                                                   32             regionprofile
#                                                   64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'comm_small', 'type': 'function'}        2              regionprofile
#                                                   4              regionprofile
#                                                   8              regionprofile
#                                                   16             regionprofile
#                                                   32             regionprofile
#                                                   64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'MPI_Recv', 'type': 'function'}          2              regionprofile
#                                                   4              regionprofile
#                                                   8              regionprofile
#                                                   16             regionprofile
#                                                   32             regionprofile
#                                                   64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'MPI_Send', 'type': 'function'}          2              regionprofile
#                                                   4              regionprofile
#                                                   8              regionprofile
#                                                   16             regionprofile
#                                                   32             regionprofile
#                                                   64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'comp', 'type': 'function'}              2              regionprofile
#                                                   4              regionprofile
#                                                   8              regionprofile
#                                                   16             regionprofile
#                                                   32             regionprofile
#                                                   64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'comp_large', 'type': 'function'}        2              regionprofile
#                                                   4              regionprofile
#                                                   8              regionprofile
#                                                   16             regionprofile
#                                                   32             regionprofile
#                                                   64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'correctness_check', 'type': 'function'} 2              regionprofile
#                                                   4              regionprofile
#                                                   8              regionprofile
#                                                   16             regionprofile
#                                                   32             regionprofile
#                                                   64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'data_init', 'type': 'function'}         2              regionprofile
#                                                   4              regionprofile
#                                                   8              regionprofile
#                                                   16             regionprofile
#                                                   32             regionprofile
#                                                   64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
#
#                                                                            \
#                                                             Avg time/rank
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2              4.197867
#                                                   4              2.411970
#                                                   8              1.700087
#                                                   16             1.556389
#                                                   32             1.937788
#                                                   64             1.848234
#                                                   128            2.324440
#                                                   256            2.440184
#                                                   512            2.758900
#                                                   1024           4.027632
# {'name': 'comm', 'type': 'function'}              2              0.230589
#                                                   4              0.317650
#                                                   8              0.352176
#                                                   16             0.372766
#                                                   32             0.381656
#                                                   64             0.398278
#                                                   128            0.403299
#                                                   256            0.406260
#                                                   512            0.312790
#                                                   1024           0.467661
# {'name': 'comm_large', 'type': 'function'}        2              0.207234
#                                                   4              0.299256
#                                                   8              0.338327
#                                                   16             0.361182
#                                                   32             0.374999
#                                                   64             0.393939
#                                                   128            0.400776
#                                                   256            0.404458
#                                                   512            0.311624
#                                                   1024           0.465938
# {'name': 'MPI_Bcast', 'type': 'function'}         2              0.185059
#                                                   4              0.277236
#                                                   8              0.322668
#                                                   16             0.347406
#                                                   32             0.363735
#                                                   64             0.369597
#                                                   128            0.379324
#                                                   256            0.385003
#                                                   512            0.287012
#                                                   1024           0.457647
# {'name': 'MPI_Scatter', 'type': 'function'}       2              0.022132
#                                                   4              0.021983
#                                                   8              0.015619
#                                                   16             0.013740
#                                                   32             0.011226
#                                                   64             0.024311
#                                                   128            0.021413
#                                                   256            0.019417
#                                                   512            0.024573
#                                                   1024           0.008261
# {'name': 'comm_small', 'type': 'function'}        2              0.023303
#                                                   4              0.018335
#                                                   8              0.013789
#                                                   16             0.011523
#                                                   32             0.006595
#                                                   64             0.004278
#                                                   128            0.002462
#                                                   256            0.001741
#                                                   512            0.001105
#                                                   1024           0.001647
# {'name': 'MPI_Recv', 'type': 'function'}          2              0.035559
#                                                   4              0.020918
#                                                   8              0.015837
#                                                   16             0.015017
#                                                   32             0.008230
#                                                   64             0.005554
#                                                   128            0.003139
#                                                   256            0.002281
#                                                   512            0.001455
#                                                   1024           0.001711
# {'name': 'MPI_Send', 'type': 'function'}          2              0.010982
#                                                   4              0.010458
#                                                   8              0.006672
#                                                   16             0.004249
#                                                   32             0.002527
#                                                   64             0.001496
#                                                   128            0.000874
#                                                   256            0.000579
#                                                   512            0.000356
#                                                   1024           0.000771
# {'name': 'comp', 'type': 'function'}              2              3.268000
#                                                   4              1.629639
#                                                   8              0.809022
#                                                   16             0.404434
#                                                   32             0.200662
#                                                   64             0.099957
#                                                   128            0.049687
#                                                   256            0.024964
#                                                   512            0.012639
#                                                   1024           0.006198
# {'name': 'comp_large', 'type': 'function'}        2              3.267930
#                                                   4              1.629586
#                                                   8              0.808979
#                                                   16             0.404395
#                                                   32             0.200625
#                                                   64             0.099922
#                                                   128            0.049656
#                                                   256            0.024935
#                                                   512            0.012613
#                                                   1024           0.006178
# {'name': 'correctness_check', 'type': 'function'} 2              0.047130
#                                                   4              0.047254
#                                                   8              0.047146
#                                                   16             0.047488
#                                                   32             0.047647
#                                                   64             0.047574
#                                                   128            0.047215
#                                                   256            0.047325
#                                                   512            0.047184
#                                                   1024           0.047219
# {'name': 'data_init', 'type': 'function'}         2              0.369466
#                                                   4              0.368271
#                                                   8              0.368357
#                                                   16             0.369305
#                                                   32             0.373560
#                                                   64             0.369208
#                                                   128            0.371362
#                                                   256            0.370731
#                                                   512            0.370203
#                                                   1024           0.371277
#
#                                                             (16777216, ReverseSorted)  \
#                                                                          spot.channel
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2                     regionprofile
#                                                   4                     regionprofile
#                                                   8                     regionprofile
#                                                   16                    regionprofile
#                                                   32                    regionprofile
#                                                   64                    regionprofile
#                                                   128                   regionprofile
#                                                   256                   regionprofile
#                                                   512                   regionprofile
#                                                   1024                  regionprofile
# {'name': 'comm', 'type': 'function'}              2                     regionprofile
#                                                   4                     regionprofile
#                                                   8                     regionprofile
#                                                   16                    regionprofile
#                                                   32                    regionprofile
#                                                   64                    regionprofile
#                                                   128                   regionprofile
#                                                   256                   regionprofile
#                                                   512                   regionprofile
#                                                   1024                  regionprofile
# {'name': 'comm_large', 'type': 'function'}        2                     regionprofile
#                                                   4                     regionprofile
#                                                   8                     regionprofile
#                                                   16                    regionprofile
#                                                   32                    regionprofile
#                                                   64                    regionprofile
#                                                   128                   regionprofile
#                                                   256                   regionprofile
#                                                   512                   regionprofile
#                                                   1024                  regionprofile
# {'name': 'MPI_Bcast', 'type': 'function'}         2                     regionprofile
#                                                   4                     regionprofile
#                                                   8                     regionprofile
#                                                   16                    regionprofile
#                                                   32                    regionprofile
#                                                   64                    regionprofile
#                                                   128                   regionprofile
#                                                   256                   regionprofile
#                                                   512                   regionprofile
#                                                   1024                  regionprofile
# {'name': 'MPI_Scatter', 'type': 'function'}       2                     regionprofile
#                                                   4                     regionprofile
#                                                   8                     regionprofile
#                                                   16                    regionprofile
#                                                   32                    regionprofile
#                                                   64                    regionprofile
#                                                   128                   regionprofile
#                                                   256                   regionprofile
#                                                   512                   regionprofile
#                                                   1024                  regionprofile
# {'name': 'comm_small', 'type': 'function'}        2                     regionprofile
#                                                   4                     regionprofile
#                                                   8                     regionprofile
#                                                   16                    regionprofile
#                                                   32                    regionprofile
#                                                   64                    regionprofile
#                                                   128                   regionprofile
#                                                   256                   regionprofile
#                                                   512                   regionprofile
#                                                   1024                  regionprofile
# {'name': 'MPI_Recv', 'type': 'function'}          2                     regionprofile
#                                                   4                     regionprofile
#                                                   8                     regionprofile
#                                                   16                    regionprofile
#                                                   32                    regionprofile
#                                                   64                    regionprofile
#                                                   128                   regionprofile
#                                                   256                   regionprofile
#                                                   512                   regionprofile
#                                                   1024                  regionprofile
# {'name': 'MPI_Send', 'type': 'function'}          2                     regionprofile
#                                                   4                     regionprofile
#                                                   8                     regionprofile
#                                                   16                    regionprofile
#                                                   32                    regionprofile
#                                                   64                    regionprofile
#                                                   128                   regionprofile
#                                                   256                   regionprofile
#                                                   512                   regionprofile
#                                                   1024                  regionprofile
# {'name': 'comp', 'type': 'function'}              2                     regionprofile
#                                                   4                     regionprofile
#                                                   8                     regionprofile
#                                                   16                    regionprofile
#                                                   32                    regionprofile
#                                                   64                    regionprofile
#                                                   128                   regionprofile
#                                                   256                   regionprofile
#                                                   512                   regionprofile
# ...
#                                                   8              0.015884
#                                                   16             0.012594
#                                                   32             0.010437
#                                                   64             0.017074
#                                                   128            0.021769
#                                                   256            0.022397
#                                                   512            0.007225
#                                                   1024           0.002921
# {'name': 'comm_small', 'type': 'function'}        2              0.014155
#                                                   4              0.015852
#                                                   8              0.013818
#                                                   16             0.009522
#                                                   32             0.006436
#                                                   64             0.003883
#                                                   128            0.002387
#                                                   256            0.001377
#                                                   512            0.002083
#                                                   1024           0.002913
# {'name': 'MPI_Recv', 'type': 'function'}          2              0.014584
#                                                   4              0.018096
#                                                   8              0.017337
#                                                   16             0.011772
#                                                   32             0.007973
#                                                   64             0.004790
#                                                   128            0.003011
#                                                   256            0.001814
#                                                   512            0.001909
#                                                   1024           0.002507
# {'name': 'MPI_Send', 'type': 'function'}          2              0.013658
#                                                   4              0.009031
#                                                   8              0.005847
#                                                   16             0.003845
#                                                   32             0.002498
#                                                   64             0.001484
#                                                   128            0.000864
#                                                   256            0.000450
#                                                   512            0.001110
#                                                   1024           0.001641
# {'name': 'comp', 'type': 'function'}              2              2.112918
#                                                   4              1.049078
#                                                   8              0.522280
#                                                   16             0.259678
#                                                   32             0.129083
#                                                   64             0.064031
#                                                   128            0.031686
#                                                   256            0.016025
#                                                   512            0.008273
#                                                   1024           0.003972
# {'name': 'comp_large', 'type': 'function'}        2              2.112856
#                                                   4              1.049037
#                                                   8              0.522240
#                                                   16             0.259641
#                                                   32             0.129048
#                                                   64             0.063998
#                                                   128            0.031657
#                                                   256            0.015997
#                                                   512            0.008250
#                                                   1024           0.003953
# {'name': 'correctness_check', 'type': 'function'} 2              0.043878
#                                                   4              0.044295
#                                                   8              0.043890
#                                                   16             0.043924
#                                                   32             0.044042
#                                                   64             0.044416
#                                                   128            0.044026
#                                                   256            0.044023
#                                                   512            0.044010
#                                                   1024           0.044015
# {'name': 'data_init', 'type': 'function'}         2              0.053990
#                                                   4              0.053600
#                                                   8              0.053877
#                                                   16             0.053666
#                                                   32             0.061985
#                                                   64             0.053408
#                                                   128            0.054333
#                                                   256            0.053736
#                                                   512            0.053733
#                                                   1024           0.053520
#
#                                                                           name
#
# node                                              num_procs
# {'name': 'main', 'type': 'function'}              2                       main
#                                                   4                       main
#                                                   8                       main
#                                                   16                      main
#                                                   32                      main
#                                                   64                      main
#                                                   128                     main
#                                                   256                     main
#                                                   512                     main
#                                                   1024                    main
# {'name': 'comm', 'type': 'function'}              2                       comm
#                                                   4                       comm
#                                                   8                       comm
#                                                   16                      comm
#                                                   32                      comm
#                                                   64                      comm
#                                                   128                     comm
#                                                   256                     comm
#                                                   512                     comm
#                                                   1024                    comm
# {'name': 'comm_large', 'type': 'function'}        2                 comm_large
#                                                   4                 comm_large
#                                                   8                 comm_large
#                                                   16                comm_large
#                                                   32                comm_large
#                                                   64                comm_large
#                                                   128               comm_large
#                                                   256               comm_large
#                                                   512               comm_large
#                                                   1024              comm_large
# {'name': 'MPI_Bcast', 'type': 'function'}         2                  MPI_Bcast
#                                                   4                  MPI_Bcast
#                                                   8                  MPI_Bcast
#                                                   16                 MPI_Bcast
#                                                   32                 MPI_Bcast
#                                                   64                 MPI_Bcast
#                                                   128                MPI_Bcast
#                                                   256                MPI_Bcast
#                                                   512                MPI_Bcast
#                                                   1024               MPI_Bcast
# {'name': 'MPI_Scatter', 'type': 'function'}       2                MPI_Scatter
#                                                   4                MPI_Scatter
#                                                   8                MPI_Scatter
#                                                   16               MPI_Scatter
#                                                   32               MPI_Scatter
#                                                   64               MPI_Scatter
#                                                   128              MPI_Scatter
#                                                   256              MPI_Scatter
#                                                   512              MPI_Scatter
#                                                   1024             MPI_Scatter
# {'name': 'comm_small', 'type': 'function'}        2                 comm_small
#                                                   4                 comm_small
#                                                   8                 comm_small
#                                                   16                comm_small
#                                                   32                comm_small
#                                                   64                comm_small
#                                                   128               comm_small
#                                                   256               comm_small
#                                                   512               comm_small
#                                                   1024              comm_small
# {'name': 'MPI_Recv', 'type': 'function'}          2                   MPI_Recv
#                                                   4                   MPI_Recv
#                                                   8                   MPI_Recv
#                                                   16                  MPI_Recv
#                                                   32                  MPI_Recv
#                                                   64                  MPI_Recv
#                                                   128                 MPI_Recv
#                                                   256                 MPI_Recv
#                                                   512                 MPI_Recv
#                                                   1024                MPI_Recv
# {'name': 'MPI_Send', 'type': 'function'}          2                   MPI_Send
#                                                   4                   MPI_Send
#                                                   8                   MPI_Send
#                                                   16                  MPI_Send
#                                                   32                  MPI_Send
#                                                   64                  MPI_Send
#                                                   128                 MPI_Send
#                                                   256                 MPI_Send
#                                                   512                 MPI_Send
#                                                   1024                MPI_Send
# {'name': 'comp', 'type': 'function'}              2                       comp
#                                                   4                       comp
#                                                   8                       comp
#                                                   16                      comp
#                                                   32                      comp
#                                                   64                      comp
#                                                   128                     comp
#                                                   256                     comp
#                                                   512                     comp
#                                                   1024                    comp
# {'name': 'comp_large', 'type': 'function'}        2                 comp_large
#                                                   4                 comp_large
#                                                   8                 comp_large
#                                                   16                comp_large
#                                                   32                comp_large
#                                                   64                comp_large
#                                                   128               comp_large
#                                                   256               comp_large
#                                                   512               comp_large
#                                                   1024              comp_large
# {'name': 'correctness_check', 'type': 'function'} 2          correctness_check
#                                                   4          correctness_check
#                                                   8          correctness_check
#                                                   16         correctness_check
#                                                   32         correctness_check
#                                                   64         correctness_check
#                                                   128        correctness_check
#                                                   256        correctness_check
#                                                   512        correctness_check
#                                                   1024       correctness_check
# {'name': 'data_init', 'type': 'function'}         2                  data_init
#                                                   4                  data_init
#                                                   8                  data_init
#                                                   16                 data_init
#                                                   32                 data_init
#                                                   64                 data_init
#                                                   128                data_init
#                                                   256                data_init
#                                                   512                data_init
#                                                   1024               data_init

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", "")], axis=1)

# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])

# %% [raw]
# ctk.dataframe

# %%
# Define common variables
function_names = set(ctk.dataframe.index.get_level_values("name"))
procs = sorted(list(set(ctk.dataframe.index.get_level_values("num_procs"))))
matrix_sizes = sorted(ctk.dataframe.columns.tolist())
#time = set(ctk.dataframe.index.get_level_values("Total time"))

# %%
ctk.dataframe.loc["main"]
# Out:
#           (16777216, 1%Perturbed)               (16777216, Random)  \
#                      spot.channel Avg time/rank       spot.channel
# num_procs
# 2                   regionprofile      2.777662      regionprofile
# 4                   regionprofile      1.553406      regionprofile
# 8                   regionprofile      1.142955      regionprofile
# 16                  regionprofile      1.095480      regionprofile
# 32                  regionprofile      1.564576      regionprofile
# 64                  regionprofile      1.483067      regionprofile
# 128                 regionprofile      1.602832      regionprofile
# 256                 regionprofile      1.883084      regionprofile
# 512                 regionprofile      2.229880      regionprofile
# 1024                regionprofile      3.190151      regionprofile
#
#                         (16777216, ReverseSorted)                \
#           Avg time/rank              spot.channel Avg time/rank
# num_procs
# 2              4.197867             regionprofile      2.741543
# 4              2.411970             regionprofile      1.528224
# 8              1.700087             regionprofile      1.099305
# 16             1.556389             regionprofile      1.107571
# 32             1.937788             regionprofile      1.535265
# 64             1.848234             regionprofile      1.482089
# 128            2.324440             regionprofile      1.563845
# 256            2.440184             regionprofile      1.748493
# 512            2.758900             regionprofile      2.201538
# 1024           4.027632             regionprofile      3.460665
#
#           (16777216, Sorted)
#                 spot.channel Avg time/rank
# num_procs
# 2              regionprofile      2.741443
# 4              regionprofile      1.509778
# 8              regionprofile      1.087477
# 16             regionprofile      1.085829
# 32             regionprofile      1.505086
# 64             regionprofile      1.496093
# 128            regionprofile      1.967590
# 256            regionprofile      1.743469
# 512            regionprofile      2.142376
# 1024           regionprofile      3.178112

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %%
for name in function_names:
    plot_pandas(
        df=ctk.dataframe.loc[name],
        title="Merge Sort | Strong Scaling | MPI | 16777216 | " + name,
        xlabel="Number of Processors",
        ylabel="Time (seconds)",
        # set to False 
        loglog=False
    )

# %%
# how to get input_sizes?
# speed up
input_sizes = set(tk.metadata["InputSize"])
for name in function_names:
    for size in input_sizes:
        temp_df = ctk.dataframe[[col for col in ctk.dataframe.columns if col[0][0] == 16777216 and col[1] == "Avg time/rank"]].loc[name]
        temp_df = temp_df.iloc[0]/temp_df

        plot_pandas (
            title = "Speed Up | MPI | 16777216 | " + name,
            xlabel = "Threads",
            ylabel = "Time (seconds)",
            # True or False? 
            loglog=False,
            df = temp_df
        )
