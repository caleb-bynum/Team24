# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
# Comment out appropriate portion
#tk = th.Thicket.from_caliperreader(glob("cali_files/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/Random/Strong_Scaling_MPI/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/MPI_Files/65536_Weak_Test/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/MPI_Files/16777216_Strong/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/CUDA_Files/65536_Strong_Compare/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/CUDA_Files/65536_Weak/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/CUDA_Files/65536_Strong/*.cali"))

# tk = th.Thicket.from_caliperreader(glob("cali_files/Aazmir/CUDA/Strong/*.cali"))
tk = th.Thicket.from_caliperreader(glob("cali_files/Aazmir/CUDA/Weak/*.cali"))

# %%
# Performance data
tk.dataframe
#CUDA
tk.dataframe = tk.dataframe.drop([('Min time/rank'),('Max time/rank'),('Total time'),("Avg time/rank"),("Min GPU time/rank"),("Max GPU time/rank"),("Total GPU time"), ('nid')], axis=1)
# tk.dataframe = tk.dataframe.drop([('Min time/rank'),('Max time/rank'),('Total time'),("Avg time/rank"), ('nid')], axis=1)

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 482621196            2.11.0-dev
# 484673912            2.11.0-dev
# 1474430778           2.11.0-dev
# 1873122814           2.11.0-dev
# 1958395705           2.11.0-dev
# 2144343713           2.11.0-dev
# 2251521482           2.11.0-dev
# 2382307816           2.11.0-dev
# 2531163818           2.11.0-dev
# 2584257613           2.11.0-dev
# 3049909339           2.11.0-dev
# 3119876716           2.11.0-dev
# 3141628640           2.11.0-dev
# 3314739971           2.11.0-dev
# 3707788091           2.11.0-dev
# 3817121124           2.11.0-dev
# 3961628931           2.11.0-dev
# 3986919364           2.11.0-dev
# 4101389376           2.11.0-dev
# 4270827816           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 482621196   min#inclusive#sum#time.duration,max#inclusive#...
# 484673912   min#inclusive#sum#time.duration,max#inclusive#...
# 1474430778  min#inclusive#sum#time.duration,max#inclusive#...
# 1873122814  min#inclusive#sum#time.duration,max#inclusive#...
# 1958395705  min#inclusive#sum#time.duration,max#inclusive#...
# 2144343713  min#inclusive#sum#time.duration,max#inclusive#...
# 2251521482  min#inclusive#sum#time.duration,max#inclusive#...
# 2382307816  min#inclusive#sum#time.duration,max#inclusive#...
# 2531163818  min#inclusive#sum#time.duration,max#inclusive#...
# 2584257613  min#inclusive#sum#time.duration,max#inclusive#...
# 3049909339  min#inclusive#sum#time.duration,max#inclusive#...
# 3119876716  min#inclusive#sum#time.duration,max#inclusive#...
# 3141628640  min#inclusive#sum#time.duration,max#inclusive#...
# 3314739971  min#inclusive#sum#time.duration,max#inclusive#...
# 3707788091  min#inclusive#sum#time.duration,max#inclusive#...
# 3817121124  min#inclusive#sum#time.duration,max#inclusive#...
# 3961628931  min#inclusive#sum#time.duration,max#inclusive#...
# 3986919364  min#inclusive#sum#time.duration,max#inclusive#...
# 4101389376  min#inclusive#sum#time.duration,max#inclusive#...
# 4270827816  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 482621196                                             2
# 484673912                                             2
# 1474430778                                            2
# 1873122814                                            2
# 1958395705                                            2
# 2144343713                                            2
# 2251521482                                            2
# 2382307816                                            2
# 2531163818                                            2
# 2584257613                                            2
# 3049909339                                            2
# 3119876716                                            2
# 3141628640                                            2
# 3314739971                                            2
# 3707788091                                            2
# 3817121124                                            2
# 3961628931                                            2
# 3986919364                                            2
# 4101389376                                            2
# 4270827816                                            2
#
#                        spot.options  spot.channels cali.channel  \
# profile
# 482621196   cuda.gputime,node.order  regionprofile         spot
# 484673912   cuda.gputime,node.order  regionprofile         spot
# 1474430778  cuda.gputime,node.order  regionprofile         spot
# 1873122814  cuda.gputime,node.order  regionprofile         spot
# 1958395705  cuda.gputime,node.order  regionprofile         spot
# 2144343713  cuda.gputime,node.order  regionprofile         spot
# 2251521482  cuda.gputime,node.order  regionprofile         spot
# 2382307816  cuda.gputime,node.order  regionprofile         spot
# 2531163818  cuda.gputime,node.order  regionprofile         spot
# 2584257613  cuda.gputime,node.order  regionprofile         spot
# 3049909339  cuda.gputime,node.order  regionprofile         spot
# 3119876716  cuda.gputime,node.order  regionprofile         spot
# 3141628640  cuda.gputime,node.order  regionprofile         spot
# 3314739971  cuda.gputime,node.order  regionprofile         spot
# 3707788091  cuda.gputime,node.order  regionprofile         spot
# 3817121124  cuda.gputime,node.order  regionprofile         spot
# 3961628931  cuda.gputime,node.order  regionprofile         spot
# 3986919364  cuda.gputime,node.order  regionprofile         spot
# 4101389376  cuda.gputime,node.order  regionprofile         spot
# 4270827816  cuda.gputime,node.order  regionprofile         spot
#
#            spot:cuda.gputime spot:node.order              spot:output  \
# profile
# 482621196               true            true  s1-t1024-v16777216.cali
# 484673912               true            true  s3-t1024-v16777216.cali
# 1474430778              true            true       s2-t64-v65536.cali
# 1873122814              true            true  s2-t1024-v16777216.cali
# 1958395705              true            true     s0-t128-v262144.cali
# 2144343713              true            true    s1-t256-v1048576.cali
# 2251521482              true            true     s1-t128-v262144.cali
# 2382307816              true            true       s3-t64-v65536.cali
# 2531163818              true            true    s0-t512-v4194304.cali
# 2584257613              true            true       s0-t64-v65536.cali
# 3049909339              true            true     s2-t128-v262144.cali
# 3119876716              true            true    s0-t256-v1048576.cali
# 3141628640              true            true    s3-t512-v4194304.cali
# 3314739971              true            true    s3-t256-v1048576.cali
# 3707788091              true            true    s1-t512-v4194304.cali
# 3817121124              true            true  s0-t1024-v16777216.cali
# 3961628931              true            true    s2-t512-v4194304.cali
# 3986919364              true            true    s2-t256-v1048576.cali
# 4101389376              true            true       s1-t64-v65536.cali
# 4270827816              true            true     s3-t128-v262144.cali
#
#             launchdate                                          libraries  \
# profile
# 482621196   1699993562  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 484673912   1699993581  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1474430778  1699993281  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1873122814  1699993572  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1958395705  1699993302  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2144343713  1699993360  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2251521482  1699993320  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2382307816  1699993281  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2531163818  1699993420  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2584257613  1699993266  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3049909339  1699993320  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3119876716  1699993360  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3141628640  1699993441  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3314739971  1699993358  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3707788091  1699993441  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3817121124  1699993562  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3961628931  1699993441  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3986919364  1699993360  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4101389376  1699993281  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4270827816  1699993320  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                        cmdline cluster        Algorithm  \
# profile
# 482621196   [./enumeration, 1024, 16777216, 1]       g  EnumerationSort
# 484673912   [./enumeration, 1024, 16777216, 3]       g  EnumerationSort
# 1474430778       [./enumeration, 64, 65536, 2]       g  EnumerationSort
# 1873122814  [./enumeration, 1024, 16777216, 2]       g  EnumerationSort
# 1958395705     [./enumeration, 128, 262144, 0]       g  EnumerationSort
# 2144343713    [./enumeration, 256, 1048576, 1]       g  EnumerationSort
# 2251521482     [./enumeration, 128, 262144, 1]       g  EnumerationSort
# 2382307816       [./enumeration, 64, 65536, 3]       g  EnumerationSort
# 2531163818    [./enumeration, 512, 4194304, 0]       g  EnumerationSort
# 2584257613       [./enumeration, 64, 65536, 0]       g  EnumerationSort
# 3049909339     [./enumeration, 128, 262144, 2]       g  EnumerationSort
# 3119876716    [./enumeration, 256, 1048576, 0]       g  EnumerationSort
# 3141628640    [./enumeration, 512, 4194304, 3]       g  EnumerationSort
# 3314739971    [./enumeration, 256, 1048576, 3]       g  EnumerationSort
# 3707788091    [./enumeration, 512, 4194304, 1]       g  EnumerationSort
# 3817121124  [./enumeration, 1024, 16777216, 0]       g  EnumerationSort
# 3961628931    [./enumeration, 512, 4194304, 2]       g  EnumerationSort
# 3986919364    [./enumeration, 256, 1048576, 2]       g  EnumerationSort
# 4101389376       [./enumeration, 64, 65536, 1]       g  EnumerationSort
# 4270827816     [./enumeration, 128, 262144, 3]       g  EnumerationSort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize  \
# profile
# 482621196              CUDA    float               4   16777216
# 484673912              CUDA    float               4   16777216
# 1474430778             CUDA    float               4      65536
# 1873122814             CUDA    float               4   16777216
# 1958395705             CUDA    float               4     262144
# 2144343713             CUDA    float               4    1048576
# 2251521482             CUDA    float               4     262144
# 2382307816             CUDA    float               4      65536
# 2531163818             CUDA    float               4    4194304
# 2584257613             CUDA    float               4      65536
# 3049909339             CUDA    float               4     262144
# 3119876716             CUDA    float               4    1048576
# 3141628640             CUDA    float               4    4194304
# 3314739971             CUDA    float               4    1048576
# 3707788091             CUDA    float               4    4194304
# 3817121124             CUDA    float               4   16777216
# 3961628931             CUDA    float               4    4194304
# 3986919364             CUDA    float               4    1048576
# 4101389376             CUDA    float               4      65536
# 4270827816             CUDA    float               4     262144
#
#                 InputType  num_procs  num_threads  num_blocks  group_num  \
# profile
# 482621196          Sorted          1         1024       16384         20
# 484673912    1%%perturbed          1         1024       16384         20
# 1474430778  ReverseSorted          1           64        1024         20
# 1873122814  ReverseSorted          1         1024       16384         20
# 1958395705         Random          1          128        2048         20
# 2144343713         Sorted          1          256        4096         20
# 2251521482         Sorted          1          128        2048         20
# 2382307816   1%%perturbed          1           64        1024         20
# 2531163818         Random          1          512        8192         20
# 2584257613         Random          1           64        1024         20
# 3049909339  ReverseSorted          1          128        2048         20
# 3119876716         Random          1          256        4096         20
# 3141628640   1%%perturbed          1          512        8192         20
# 3314739971   1%%perturbed          1          256        4096         20
# 3707788091         Sorted          1          512        8192         20
# 3817121124         Random          1         1024       16384         20
# 3961628931  ReverseSorted          1          512        8192         20
# 3986919364  ReverseSorted          1          256        4096         20
# 4101389376         Sorted          1           64        1024         20
# 4270827816   1%%perturbed          1          128        2048         20
#
#            implementation_source
# profile
# 482621196                 Online
# 484673912                 Online
# 1474430778                Online
# 1873122814                Online
# 1958395705                Online
# 2144343713                Online
# 2251521482                Online
# 2382307816                Online
# 2531163818                Online
# 2584257613                Online
# 3049909339                Online
# 3119876716                Online
# 3141628640                Online
# 3314739971                Online
# 3707788091                Online
# 3817121124                Online
# 3961628931                Online
# 3986919364                Online
# 4101389376                Online
# 4270827816                Online

# %%
tk.metadata
tk.statsframe.dataframe["time"] = 1
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.0
#
# 1.000 main
# ├─ 1.000 comm
# │  └─ 1.000 comm_large
# │     └─ 1.000 cudaMemcpy
# ├─ 1.000 comp
# │  └─ 1.000 comp_large
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
# strong
# gb = tk.groupby([("InputSize"), ("Algorithm")])
# gb = tk.groupby([("InputSize"), ("InputType")])
# weak
gb = tk.groupby([("InputType")])
# Out:
# 4  thickets created...
# {('1%%perturbed',): <thicket.thicket.Thicket object at 0x2b23bfca8f40>, ('Random',): <thicket.thicket.Thicket object at 0x2b23bf5d4df0>, ('ReverseSorted',): <thicket.thicket.Thicket object at 0x2b23bccb0dc0>, ('Sorted',): <thicket.thicket.Thicket object at 0x2b23bffd9220>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_threads"
)

# %%
ctk.dataframe
# Out:
#                                                               (1%%perturbed,)  \
#                                                                  spot.channel
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'comm', 'type': 'function'}              64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'comm_large', 'type': 'function'}        64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'cudaMemcpy', 'type': 'function'}        64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'comp', 'type': 'function'}              64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'comp_large', 'type': 'function'}        64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'correctness_check', 'type': 'function'} 64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'data_init', 'type': 'function'}         64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
#
#                                                                                  \
#                                                               Avg GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.006044
#                                                   128                  0.080274
#                                                   256                  0.821830
#                                                   512                 11.377031
#                                                   1024               180.190352
# {'name': 'comm', 'type': 'function'}              64                   0.000049
#                                                   128                  0.000175
#                                                   256                  0.001820
#                                                   512                  0.009067
#                                                   1024                 0.038303
# {'name': 'comm_large', 'type': 'function'}        64                   0.000049
#                                                   128                  0.000175
#                                                   256                  0.001820
#                                                   512                  0.009067
#                                                   1024                 0.038303
# {'name': 'cudaMemcpy', 'type': 'function'}        64                   0.000049
#                                                   128                  0.000175
#                                                   256                  0.001820
#                                                   512                  0.009067
#                                                   1024                 0.038303
# {'name': 'comp', 'type': 'function'}              64                   0.005995
#                                                   128                  0.080099
#                                                   256                  0.820010
#                                                   512                 11.367964
#                                                   1024               180.152049
# {'name': 'comp_large', 'type': 'function'}        64                   0.005995
#                                                   128                  0.080099
#                                                   256                  0.820010
#                                                   512                 11.367964
#                                                   1024               180.152049
# {'name': 'correctness_check', 'type': 'function'} 64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                                    (Random,)  \
#                                                                 spot.channel
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm_large', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'cudaMemcpy', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp_large', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'correctness_check', 'type': 'function'} 64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'data_init', 'type': 'function'}         64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
#
#                                                                                  \
#                                                               Avg GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.004565
#                                                   128                  0.046622
#                                                   256                  0.832795
#                                                   512                 11.480100
#                                                   1024               181.386652
# {'name': 'comm', 'type': 'function'}              64                   0.000048
#                                                   128                  0.000171
#                                                   256                  0.001724
#                                                   512                  0.009297
#                                                   1024                 0.039513
# {'name': 'comm_large', 'type': 'function'}        64                   0.000048
#                                                   128                  0.000171
#                                                   256                  0.001724
#                                                   512                  0.009297
#                                                   1024                 0.039513
# {'name': 'cudaMemcpy', 'type': 'function'}        64                   0.000048
#                                                   128                  0.000171
#                                                   256                  0.001724
#                                                   512                  0.009297
#                                                   1024                 0.039513
# {'name': 'comp', 'type': 'function'}              64                   0.004518
#                                                   128                  0.046451
#                                                   256                  0.831070
#                                                   512                 11.470804
#                                                   1024               181.347139
# {'name': 'comp_large', 'type': 'function'}        64                   0.004518
#                                                   128                  0.046451
#                                                   256                  0.831070
#                                                   512                 11.470804
#                                                   1024               181.347139
# {'name': 'correctness_check', 'type': 'function'} 64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                               (ReverseSorted,)  \
#                                                                   spot.channel
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'comm', 'type': 'function'}              64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'comm_large', 'type': 'function'}        64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'cudaMemcpy', 'type': 'function'}        64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'comp', 'type': 'function'}              64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'comp_large', 'type': 'function'}        64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'correctness_check', 'type': 'function'} 64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
# {'name': 'data_init', 'type': 'function'}         64             regionprofile
#                                                   128            regionprofile
#                                                   256            regionprofile
#                                                   512            regionprofile
#                                                   1024           regionprofile
#
#                                                                                  \
#                                                               Avg GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.005015
#                                                   128                  0.084748
#                                                   256                  0.794110
#                                                   512                 11.359467
#                                                   1024               179.451092
# {'name': 'comm', 'type': 'function'}              64                   0.000048
#                                                   128                  0.000174
#                                                   256                  0.001789
#                                                   512                  0.009518
#                                                   1024                 0.039866
# {'name': 'comm_large', 'type': 'function'}        64                   0.000048
#                                                   128                  0.000174
#                                                   256                  0.001789
#                                                   512                  0.009518
#                                                   1024                 0.039866
# {'name': 'cudaMemcpy', 'type': 'function'}        64                   0.000048
#                                                   128                  0.000174
#                                                   256                  0.001789
#                                                   512                  0.009518
#                                                   1024                 0.039866
# {'name': 'comp', 'type': 'function'}              64                   0.004967
#                                                   128                  0.084575
#                                                   256                  0.792321
#                                                   512                 11.349949
#                                                   1024               179.411226
# {'name': 'comp_large', 'type': 'function'}        64                   0.004967
#                                                   128                  0.084575
#                                                   256                  0.792321
#                                                   512                 11.349949
#                                                   1024               179.411226
# {'name': 'correctness_check', 'type': 'function'} 64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                                    (Sorted,)  \
#                                                                 spot.channel
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm_large', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'cudaMemcpy', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp', 'type': 'function'}              64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp_large', 'type': 'function'}        64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'correctness_check', 'type': 'function'} 64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'data_init', 'type': 'function'}         64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
#
#                                                                                  \
#                                                               Avg GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                   0.005451
#                                                   128                  0.060891
#                                                   256                  0.830591
#                                                   512                 11.329908
#                                                   1024               179.703832
# {'name': 'comm', 'type': 'function'}              64                   0.000049
#                                                   128                  0.000172
#                                                   256                  0.001803
#                                                   512                  0.009367
#                                                   1024                 0.038273
# {'name': 'comm_large', 'type': 'function'}        64                   0.000049
#                                                   128                  0.000172
#                                                   256                  0.001803
#                                                   512                  0.009367
#                                                   1024                 0.038273
# {'name': 'cudaMemcpy', 'type': 'function'}        64                   0.000049
#                                                   128                  0.000172
#                                                   256                  0.001803
#                                                   512                  0.009367
#                                                   1024                 0.038273
# {'name': 'comp', 'type': 'function'}              64                   0.005402
#                                                   128                  0.060719
#                                                   256                  0.828788
#                                                   512                 11.320542
#                                                   1024               179.665558
# {'name': 'comp_large', 'type': 'function'}        64                   0.005402
#                                                   128                  0.060719
#                                                   256                  0.828788
#                                                   512                 11.320542
#                                                   1024               179.665558
# {'name': 'correctness_check', 'type': 'function'} 64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                                             name
#
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              64                        main
#                                                   128                       main
#                                                   256                       main
#                                                   512                       main
#                                                   1024                      main
# {'name': 'comm', 'type': 'function'}              64                        comm
#                                                   128                       comm
#                                                   256                       comm
#                                                   512                       comm
#                                                   1024                      comm
# {'name': 'comm_large', 'type': 'function'}        64                  comm_large
#                                                   128                 comm_large
#                                                   256                 comm_large
#                                                   512                 comm_large
#                                                   1024                comm_large
# {'name': 'cudaMemcpy', 'type': 'function'}        64                  cudaMemcpy
#                                                   128                 cudaMemcpy
#                                                   256                 cudaMemcpy
#                                                   512                 cudaMemcpy
#                                                   1024                cudaMemcpy
# {'name': 'comp', 'type': 'function'}              64                        comp
#                                                   128                       comp
#                                                   256                       comp
#                                                   512                       comp
#                                                   1024                      comp
# {'name': 'comp_large', 'type': 'function'}        64                  comp_large
#                                                   128                 comp_large
#                                                   256                 comp_large
#                                                   512                 comp_large
#                                                   1024                comp_large
# {'name': 'correctness_check', 'type': 'function'} 64           correctness_check
#                                                   128          correctness_check
#                                                   256          correctness_check
#                                                   512          correctness_check
#                                                   1024         correctness_check
# {'name': 'data_init', 'type': 'function'}         64                   data_init
#                                                   128                  data_init
#                                                   256                  data_init
#                                                   512                  data_init
#                                                   1024                 data_init

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", "")], axis=1)
# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

# %% [raw]
# ctk.dataframe

# %%
# Define common variables
function_names = set(ctk.dataframe.index.get_level_values("name"))
procs = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
matrix_sizes = sorted(ctk.dataframe.columns.tolist())

# %%
ctk.dataframe.loc["main"]
# Out:
#             (1%%perturbed,)                        (Random,)  \
#                spot.channel Avg GPU time/rank   spot.channel
# num_threads
# 64            regionprofile          0.006044  regionprofile
# 128           regionprofile          0.080274  regionprofile
# 256           regionprofile          0.821830  regionprofile
# 512           regionprofile         11.377031  regionprofile
# 1024          regionprofile        180.190352  regionprofile
#
#                               (ReverseSorted,)                    \
#             Avg GPU time/rank     spot.channel Avg GPU time/rank
# num_threads
# 64                   0.004565    regionprofile          0.005015
# 128                  0.046622    regionprofile          0.084748
# 256                  0.832795    regionprofile          0.794110
# 512                 11.480100    regionprofile         11.359467
# 1024               181.386652    regionprofile        179.451092
#
#                  (Sorted,)
#               spot.channel Avg GPU time/rank
# num_threads
# 64           regionprofile          0.005451
# 128          regionprofile          0.060891
# 256          regionprofile          0.830591
# 512          regionprofile         11.329908
# 1024         regionprofile        179.703832

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %%
for name in function_names:
    plot_pandas(
        df=ctk.dataframe.loc[name],
        title="Enumeration Sort | Weak Scaling | CUDA | " + name,
        xlabel="Number of Threads",
        ylabel="Time (seconds)",
        # set to False 
        loglog=False
    )

# %%
        temp_df = ctk.dataframe[[col for col in ctk.dataframe.columns if col[0][0] == 65536 and col[1] == "Avg GPU time/rank"]].loc[name]
        temp_df = temp_df.iloc[0]/temp_df

# %%
# how to get input_sizes?
# speed up
input_sizes = set(tk.metadata["InputSize"])
for name in function_names:
    for size in input_sizes:
        temp_df = ctk.dataframe[[col for col in ctk.dataframe.columns if col[0][0] == 65536 and col[1] == "Avg GPU time/rank"]].loc[name]
        temp_df = temp_df.iloc[0]/temp_df

        plot_pandas (
            title = "Speed Up | CUDA | " + name,
            xlabel = "Threads",
            ylabel = "Time (seconds)",
            # True or False? 
            loglog=False,
            df = temp_df
        )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-c1109f436b27> in <module>
#       7         temp_df = temp_df.iloc[0]/temp_df
#       8
# ----> 9         plot_pandas (
#      10             title = "Speed Up | CUDA | " + name,
#      11             xlabel = "Threads",
#
# <ipython-input-142-9324f1c8c1e1> in plot_pandas(df, title, xlabel, ylabel, loglog)
#       1 def plot_pandas(df, title, xlabel, ylabel, loglog):
# ----> 2     plot = df.plot(kind="line",
#       3         marker='o',
#       4         title=title,
#       5         xlabel=xlabel,
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     973                     data.columns = label_name
#     974
# --> 975         return plot_backend.plot(data, kind=kind, **kwargs)
#     976
#     977     __call__.__doc__ = __doc__
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     444     def generate(self) -> None:
#     445         self._args_adjust()
# --> 446         self._compute_plot_data()
#     447         self._setup_subplots()
#     448         self._make_plot()
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     630         # no non-numeric frames or series allowed
#     631         if is_empty:
# --> 632             raise TypeError("no numeric data to plot")
#     633
#     634         self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot
