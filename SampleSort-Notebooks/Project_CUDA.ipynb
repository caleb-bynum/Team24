# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
# Comment out appropriate portion
#tk = th.Thicket.from_caliperreader(glob("cali_files/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/Random/Strong_Scaling_MPI/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/MPI_Files/65536_Weak_Test/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/MPI_Files/16777216_Strong/*.cali"))

tk = th.Thicket.from_caliperreader(glob("CUDA-StrongScaling/*.cali"))

# %%
# Performance data
tk.dataframe
#CUDA
tk.dataframe = tk.dataframe.drop([('Min time/rank'),('Max time/rank'),('Total time'),("Avg time/rank"),("Min GPU time/rank"),("Max GPU time/rank"),("Total GPU time"), ('nid')], axis=1)

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 65506162             2.11.0-dev
# 579321731            2.11.0-dev
# 585282887            2.11.0-dev
# 1177790369           2.11.0-dev
# 1224967593           2.11.0-dev
# 1259742460           2.11.0-dev
# 1473938425           2.11.0-dev
# 1530679025           2.11.0-dev
# 1563736504           2.11.0-dev
# 1722014528           2.11.0-dev
# 1839297079           2.11.0-dev
# 1857127205           2.11.0-dev
# 2033614150           2.11.0-dev
# 2036969984           2.11.0-dev
# 2089120466           2.11.0-dev
# 2122824275           2.11.0-dev
# 2145704936           2.11.0-dev
# 2198764377           2.11.0-dev
# 2556860966           2.11.0-dev
# 2703709136           2.11.0-dev
# 2764477321           2.11.0-dev
# 2933689360           2.11.0-dev
# 2934141381           2.11.0-dev
# 2962505117           2.11.0-dev
# 3352181038           2.11.0-dev
# 3465042369           2.11.0-dev
# 3576902805           2.11.0-dev
# 3615503755           2.11.0-dev
# 3616185850           2.11.0-dev
# 3777360635           2.11.0-dev
# 3881841735           2.11.0-dev
# 3893158826           2.11.0-dev
# 4026160904           2.11.0-dev
# 4077243396           2.11.0-dev
# 4096164817           2.11.0-dev
# 4221644057           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 65506162    min#inclusive#sum#time.duration,max#inclusive#...
# 579321731   min#inclusive#sum#time.duration,max#inclusive#...
# 585282887   min#inclusive#sum#time.duration,max#inclusive#...
# 1177790369  min#inclusive#sum#time.duration,max#inclusive#...
# 1224967593  min#inclusive#sum#time.duration,max#inclusive#...
# 1259742460  min#inclusive#sum#time.duration,max#inclusive#...
# 1473938425  min#inclusive#sum#time.duration,max#inclusive#...
# 1530679025  min#inclusive#sum#time.duration,max#inclusive#...
# 1563736504  min#inclusive#sum#time.duration,max#inclusive#...
# 1722014528  min#inclusive#sum#time.duration,max#inclusive#...
# 1839297079  min#inclusive#sum#time.duration,max#inclusive#...
# 1857127205  min#inclusive#sum#time.duration,max#inclusive#...
# 2033614150  min#inclusive#sum#time.duration,max#inclusive#...
# 2036969984  min#inclusive#sum#time.duration,max#inclusive#...
# 2089120466  min#inclusive#sum#time.duration,max#inclusive#...
# 2122824275  min#inclusive#sum#time.duration,max#inclusive#...
# 2145704936  min#inclusive#sum#time.duration,max#inclusive#...
# 2198764377  min#inclusive#sum#time.duration,max#inclusive#...
# 2556860966  min#inclusive#sum#time.duration,max#inclusive#...
# 2703709136  min#inclusive#sum#time.duration,max#inclusive#...
# 2764477321  min#inclusive#sum#time.duration,max#inclusive#...
# 2933689360  min#inclusive#sum#time.duration,max#inclusive#...
# 2934141381  min#inclusive#sum#time.duration,max#inclusive#...
# 2962505117  min#inclusive#sum#time.duration,max#inclusive#...
# 3352181038  min#inclusive#sum#time.duration,max#inclusive#...
# 3465042369  min#inclusive#sum#time.duration,max#inclusive#...
# 3576902805  min#inclusive#sum#time.duration,max#inclusive#...
# 3615503755  min#inclusive#sum#time.duration,max#inclusive#...
# 3616185850  min#inclusive#sum#time.duration,max#inclusive#...
# 3777360635  min#inclusive#sum#time.duration,max#inclusive#...
# 3881841735  min#inclusive#sum#time.duration,max#inclusive#...
# 3893158826  min#inclusive#sum#time.duration,max#inclusive#...
# 4026160904  min#inclusive#sum#time.duration,max#inclusive#...
# 4077243396  min#inclusive#sum#time.duration,max#inclusive#...
# 4096164817  min#inclusive#sum#time.duration,max#inclusive#...
# 4221644057  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 65506162                                              2
# 579321731                                             2
# 585282887                                             2
# 1177790369                                            2
# 1224967593                                            2
# 1259742460                                            2
# 1473938425                                            2
# 1530679025                                            2
# 1563736504                                            2
# 1722014528                                            2
# 1839297079                                            2
# 1857127205                                            2
# 2033614150                                            2
# 2036969984                                            2
# 2089120466                                            2
# 2122824275                                            2
# 2145704936                                            2
# 2198764377                                            2
# 2556860966                                            2
# 2703709136                                            2
# 2764477321                                            2
# 2933689360                                            2
# 2934141381                                            2
# 2962505117                                            2
# 3352181038                                            2
# 3465042369                                            2
# 3576902805                                            2
# 3615503755                                            2
# 3616185850                                            2
# 3777360635                                            2
# 3881841735                                            2
# 3893158826                                            2
# 4026160904                                            2
# 4077243396                                            2
# 4096164817                                            2
# 4221644057                                            2
#
#                        spot.options  spot.channels cali.channel  \
# profile
# 65506162    cuda.gputime,node.order  regionprofile         spot
# 579321731   cuda.gputime,node.order  regionprofile         spot
# 585282887   cuda.gputime,node.order  regionprofile         spot
# 1177790369  cuda.gputime,node.order  regionprofile         spot
# 1224967593  cuda.gputime,node.order  regionprofile         spot
# 1259742460  cuda.gputime,node.order  regionprofile         spot
# 1473938425  cuda.gputime,node.order  regionprofile         spot
# 1530679025  cuda.gputime,node.order  regionprofile         spot
# 1563736504  cuda.gputime,node.order  regionprofile         spot
# 1722014528  cuda.gputime,node.order  regionprofile         spot
# 1839297079  cuda.gputime,node.order  regionprofile         spot
# 1857127205  cuda.gputime,node.order  regionprofile         spot
# 2033614150  cuda.gputime,node.order  regionprofile         spot
# 2036969984  cuda.gputime,node.order  regionprofile         spot
# 2089120466  cuda.gputime,node.order  regionprofile         spot
# 2122824275  cuda.gputime,node.order  regionprofile         spot
# 2145704936  cuda.gputime,node.order  regionprofile         spot
# 2198764377  cuda.gputime,node.order  regionprofile         spot
# 2556860966  cuda.gputime,node.order  regionprofile         spot
# 2703709136  cuda.gputime,node.order  regionprofile         spot
# 2764477321  cuda.gputime,node.order  regionprofile         spot
# 2933689360  cuda.gputime,node.order  regionprofile         spot
# 2934141381  cuda.gputime,node.order  regionprofile         spot
# 2962505117  cuda.gputime,node.order  regionprofile         spot
# 3352181038  cuda.gputime,node.order  regionprofile         spot
# 3465042369  cuda.gputime,node.order  regionprofile         spot
# 3576902805  cuda.gputime,node.order  regionprofile         spot
# 3615503755  cuda.gputime,node.order  regionprofile         spot
# 3616185850  cuda.gputime,node.order  regionprofile         spot
# 3777360635  cuda.gputime,node.order  regionprofile         spot
# 3881841735  cuda.gputime,node.order  regionprofile         spot
# 3893158826  cuda.gputime,node.order  regionprofile         spot
# 4026160904  cuda.gputime,node.order  regionprofile         spot
# 4077243396  cuda.gputime,node.order  regionprofile         spot
# 4096164817  cuda.gputime,node.order  regionprofile         spot
# 4221644057  cuda.gputime,node.order  regionprofile         spot
#
#            spot:cuda.gputime spot:node.order        spot:output  launchdate  \
# profile
# 65506162                true            true     t4-v65536.cali  1700109746
# 579321731               true            true     t4-v65536.cali  1702023240
# 585282887               true            true   t128-v65536.cali  1702023293
# 1177790369              true            true     t8-v65536.cali  1702023252
# 1224967593              true            true   t512-v65536.cali  1702022972
# 1259742460              true            true     t4-v65536.cali  1702021872
# 1473938425              true            true    t16-v65536.cali  1702023270
# 1530679025              true            true   t512-v65536.cali  1702011219
# 1563736504              true            true   t512-v65536.cali  1702022179
# 1722014528              true            true     t8-v65536.cali  1702022853
# 1839297079              true            true    t64-v65536.cali  1702023293
# 1857127205              true            true    t32-v65536.cali  1702022893
# 2033614150              true            true    t32-v65536.cali  1702021993
# 2036969984              true            true     t4-v65536.cali  1702022846
# 2089120466              true            true    t64-v65536.cali  1702021993
# 2122824275              true            true     t8-v65536.cali  1702021892
# 2145704936              true            true   t256-v65536.cali  1702023301
# 2198764377              true            true  t1024-v65536.cali  1702022992
# 2556860966              true            true    t64-v65536.cali  1701906621
# 2703709136              true            true     t8-v65536.cali  1700113472
# 2764477321              true            true   t512-v65536.cali  1702023301
# 2933689360              true            true    t16-v65536.cali  1702021905
# 2934141381              true            true  t1024-v65536.cali  1702022432
# 2962505117              true            true   t128-v65536.cali  1702022149
# 3352181038              true            true  t1024-v65536.cali  1702011261
# 3465042369              true            true    t64-v65536.cali  1702022907
# 3576902805              true            true   t256-v65536.cali  1702022952
# 3615503755              true            true   t128-v65536.cali  1702022932
# 3616185850              true            true  t1024-v65536.cali  1702023314
# 3777360635              true            true   t128-v65536.cali  1702011337
# 3881841735              true            true   t256-v65536.cali  1702011138
# 3893158826              true            true    t16-v65536.cali  1700113472
# 4026160904              true            true   t256-v65536.cali  1702022153
# 4077243396              true            true    t16-v65536.cali  1702022877
# 4096164817              true            true    t32-v65536.cali  1701907112
# 4221644057              true            true    t32-v65536.cali  1702023273
#
#                                                     libraries  \
# profile
# 65506162    [/scratch/group/csce435-f23/Caliper/caliper/li...
# 579321731   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 585282887   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1177790369  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1224967593  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1259742460  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1473938425  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1530679025  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1563736504  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1722014528  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1839297079  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1857127205  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2033614150  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2036969984  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2089120466  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2122824275  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2145704936  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2198764377  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2556860966  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2703709136  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2764477321  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2933689360  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2934141381  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2962505117  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3352181038  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3465042369  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3576902805  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3615503755  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3616185850  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3777360635  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3881841735  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3893158826  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4026160904  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4077243396  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4096164817  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4221644057  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                           cmdline cluster   Algorithm ProgrammingModel  \
# profile
# 65506162       [./Sort, 4, 65536]       g  SampleSort             CUDA
# 579321731      [./Sort, 4, 65536]       g  SampleSort             CUDA
# 585282887    [./Sort, 128, 65536]       g  SampleSort             CUDA
# 1177790369     [./Sort, 8, 65536]       g  SampleSort             CUDA
# 1224967593   [./Sort, 512, 65536]       g  SampleSort             CUDA
# 1259742460     [./Sort, 4, 65536]       g  SampleSort             CUDA
# 1473938425    [./Sort, 16, 65536]       g  SampleSort             CUDA
# 1530679025   [./Sort, 512, 65536]       g  SampleSort             CUDA
# 1563736504   [./Sort, 512, 65536]       g  SampleSort             CUDA
# 1722014528     [./Sort, 8, 65536]       g  SampleSort             CUDA
# 1839297079    [./Sort, 64, 65536]       g  SampleSort             CUDA
# 1857127205    [./Sort, 32, 65536]       g  SampleSort             CUDA
# 2033614150    [./Sort, 32, 65536]       g  SampleSort             CUDA
# 2036969984     [./Sort, 4, 65536]       g  SampleSort             CUDA
# 2089120466    [./Sort, 64, 65536]       g  SampleSort             CUDA
# 2122824275     [./Sort, 8, 65536]       g  SampleSort             CUDA
# 2145704936   [./Sort, 256, 65536]       g  SampleSort             CUDA
# 2198764377  [./Sort, 1024, 65536]       g  SampleSort             CUDA
# 2556860966    [./Sort, 64, 65536]       g  SampleSort             CUDA
# 2703709136     [./Sort, 8, 65536]       g  SampleSort             CUDA
# 2764477321   [./Sort, 512, 65536]       g  SampleSort             CUDA
# 2933689360    [./Sort, 16, 65536]       g  SampleSort             CUDA
# 2934141381  [./Sort, 1024, 65536]       g  SampleSort             CUDA
# 2962505117   [./Sort, 128, 65536]       g  SampleSort             CUDA
# 3352181038  [./Sort, 1024, 65536]       g  SampleSort             CUDA
# 3465042369    [./Sort, 64, 65536]       g  SampleSort             CUDA
# 3576902805   [./Sort, 256, 65536]       g  SampleSort             CUDA
# 3615503755   [./Sort, 128, 65536]       g  SampleSort             CUDA
# 3616185850  [./Sort, 1024, 65536]       g  SampleSort             CUDA
# 3777360635   [./Sort, 128, 65536]       g  SampleSort             CUDA
# 3881841735   [./Sort, 256, 65536]       g  SampleSort             CUDA
# 3893158826    [./Sort, 16, 65536]       g  SampleSort             CUDA
# 4026160904   [./Sort, 256, 65536]       g  SampleSort             CUDA
# 4077243396    [./Sort, 16, 65536]       g  SampleSort             CUDA
# 4096164817    [./Sort, 32, 65536]       g  SampleSort             CUDA
# 4221644057    [./Sort, 32, 65536]       g  SampleSort             CUDA
#
#            Datatype  SizeOfDatatype  InputSize      InputType  num_threads  \
# profile
# 65506162      float               4      65536         Random            4
# 579321731     float               4      65536    1%perturbed            4
# 585282887     float               4      65536    1%perturbed          128
# 1177790369    float               4      65536    1%perturbed            8
# 1224967593    float               4      65536  Reversesorted          512
# 1259742460    float               4      65536         Sorted            4
# 1473938425    float               4      65536    1%perturbed           16
# 1530679025    float               4      65536         Random          512
# 1563736504    float               4      65536         Sorted          512
# 1722014528    float               4      65536  Reversesorted            8
# 1839297079    float               4      65536    1%perturbed           64
# 1857127205    float               4      65536  Reversesorted           32
# 2033614150    float               4      65536         Sorted           32
# 2036969984    float               4      65536  Reversesorted            4
# 2089120466    float               4      65536         Sorted           64
# 2122824275    float               4      65536         Sorted            8
# 2145704936    float               4      65536    1%perturbed          256
# 2198764377    float               4      65536  Reversesorted         1024
# 2556860966    float               4      65536         Random           64
# 2703709136    float               4      65536         Random            8
# 2764477321    float               4      65536    1%perturbed          512
# 2933689360    float               4      65536         Sorted           16
# 2934141381    float               4      65536         Sorted         1024
# 2962505117    float               4      65536         Sorted          128
# 3352181038    float               4      65536         Random         1024
# 3465042369    float               4      65536  Reversesorted           64
# 3576902805    float               4      65536  Reversesorted          256
# 3615503755    float               4      65536  Reversesorted          128
# 3616185850    float               4      65536    1%perturbed         1024
# 3777360635    float               4      65536         Random          128
# 3881841735    float               4      65536         Random          256
# 3893158826    float               4      65536         Random           16
# 4026160904    float               4      65536         Sorted          256
# 4077243396    float               4      65536  Reversesorted           16
# 4096164817    float               4      65536         Random           32
# 4221644057    float               4      65536    1%perturbed           32
#
#             num_blocks  group_num                  implementation_source
# profile
# 65506162             1         24  Handwritten with some reference to AI
# 579321731            1         24  Handwritten with some reference to AI
# 585282887           32         24  Handwritten with some reference to AI
# 1177790369           2         24  Handwritten with some reference to AI
# 1224967593         128         24  Handwritten with some reference to AI
# 1259742460           1         24  Handwritten with some reference to AI
# 1473938425           4         24  Handwritten with some reference to AI
# 1530679025         128         24  Handwritten with some reference to AI
# 1563736504         128         24  Handwritten with some reference to AI
# 1722014528           2         24  Handwritten with some reference to AI
# 1839297079          16         24  Handwritten with some reference to AI
# 1857127205           8         24  Handwritten with some reference to AI
# 2033614150           8         24  Handwritten with some reference to AI
# 2036969984           1         24  Handwritten with some reference to AI
# 2089120466          16         24  Handwritten with some reference to AI
# 2122824275           2         24  Handwritten with some reference to AI
# 2145704936          64         24  Handwritten with some reference to AI
# 2198764377         256         24  Handwritten with some reference to AI
# 2556860966          16         24  Handwritten with some reference to AI
# 2703709136           2         24  Handwritten with some reference to AI
# 2764477321         128         24  Handwritten with some reference to AI
# 2933689360           4         24  Handwritten with some reference to AI
# 2934141381         256         24  Handwritten with some reference to AI
# 2962505117          32         24  Handwritten with some reference to AI
# 3352181038         256         24  Handwritten with some reference to AI
# 3465042369          16         24  Handwritten with some reference to AI
# 3576902805          64         24  Handwritten with some reference to AI
# 3615503755          32         24  Handwritten with some reference to AI
# 3616185850         256         24  Handwritten with some reference to AI
# 3777360635          32         24  Handwritten with some reference to AI
# 3881841735          64         24  Handwritten with some reference to AI
# 3893158826           4         24  Handwritten with some reference to AI
# 4026160904          64         24  Handwritten with some reference to AI
# 4077243396           4         24  Handwritten with some reference to AI
# 4096164817           8         24  Handwritten with some reference to AI
# 4221644057           8         24  Handwritten with some reference to AI

# %%
tk.metadata
tk.statsframe.dataframe["time"] = 1
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.1
#
# 1.000 main
# ├─ 1.000 comm
# │  ├─ 1.000 comm_large
# │  └─ 1.000 comm_small
# ├─ 1.000 correctness_check
# └─ 1.000 data_init
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
# strong
gb = tk.groupby([("InputSize"), ("InputType")])
# weak
# gb = tk.groupby([("InputType")])
# Out:
# 4  thickets created...
# {(65536, '1%perturbed'): <thicket.thicket.Thicket object at 0x15b536b10>, (65536, 'Random'): <thicket.thicket.Thicket object at 0x15b9d7610>, (65536, 'Reversesorted'): <thicket.thicket.Thicket object at 0x15aed5c50>, (65536, 'Sorted'): <thicket.thicket.Thicket object at 0x15b528190>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_threads"
)

# %%
ctk.dataframe
# Out:
#                                                               (65536, 1%perturbed)  \
#                                                                       spot.channel
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              4                  regionprofile
#                                                   8                  regionprofile
#                                                   16                 regionprofile
#                                                   32                 regionprofile
#                                                   64                 regionprofile
#                                                   128                regionprofile
#                                                   256                regionprofile
#                                                   512                regionprofile
#                                                   1024               regionprofile
# {'name': 'comm', 'type': 'function'}              4                  regionprofile
#                                                   8                  regionprofile
#                                                   16                 regionprofile
#                                                   32                 regionprofile
#                                                   64                 regionprofile
#                                                   128                regionprofile
#                                                   256                regionprofile
#                                                   512                regionprofile
#                                                   1024               regionprofile
# {'name': 'comm_large', 'type': 'function'}        4                  regionprofile
#                                                   8                  regionprofile
#                                                   16                 regionprofile
#                                                   32                 regionprofile
#                                                   64                 regionprofile
#                                                   128                regionprofile
#                                                   256                regionprofile
#                                                   512                regionprofile
#                                                   1024               regionprofile
# {'name': 'comm_small', 'type': 'function'}        4                  regionprofile
#                                                   8                  regionprofile
#                                                   16                 regionprofile
#                                                   32                 regionprofile
#                                                   64                 regionprofile
#                                                   128                regionprofile
#                                                   256                regionprofile
#                                                   512                regionprofile
#                                                   1024               regionprofile
# {'name': 'correctness_check', 'type': 'function'} 4                  regionprofile
#                                                   8                  regionprofile
#                                                   16                 regionprofile
#                                                   32                 regionprofile
#                                                   64                 regionprofile
#                                                   128                regionprofile
#                                                   256                regionprofile
#                                                   512                regionprofile
#                                                   1024               regionprofile
# {'name': 'data_init', 'type': 'function'}         4                  regionprofile
#                                                   8                  regionprofile
#                                                   16                 regionprofile
#                                                   32                 regionprofile
#                                                   64                 regionprofile
#                                                   128                regionprofile
#                                                   256                regionprofile
#                                                   512                regionprofile
#                                                   1024               regionprofile
#
#                                                                                  \
#                                                               Avg GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              4                    0.001140
#                                                   8                    0.001007
#                                                   16                   0.000976
#                                                   32                   0.001160
#                                                   64                   0.000869
#                                                   128                  0.000893
#                                                   256                  0.001095
#                                                   512                  0.001082
#                                                   1024                 0.000837
# {'name': 'comm', 'type': 'function'}              4                    0.000052
#                                                   8                    0.000051
#                                                   16                   0.000050
#                                                   32                   0.000052
#                                                   64                   0.000050
#                                                   128                  0.000051
#                                                   256                  0.000052
#                                                   512                  0.000052
#                                                   1024                 0.000050
# {'name': 'comm_large', 'type': 'function'}        4                    0.000052
#                                                   8                    0.000051
#                                                   16                   0.000050
#                                                   32                   0.000052
#                                                   64                   0.000050
#                                                   128                  0.000051
#                                                   256                  0.000052
#                                                   512                  0.000052
#                                                   1024                 0.000050
# {'name': 'comm_small', 'type': 'function'}        4                         NaN
#                                                   8                         NaN
#                                                   16                        NaN
#                                                   32                        NaN
#                                                   64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'correctness_check', 'type': 'function'} 4                         NaN
#                                                   8                         NaN
#                                                   16                        NaN
#                                                   32                        NaN
#                                                   64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         4                         NaN
#                                                   8                         NaN
#                                                   16                        NaN
#                                                   32                        NaN
#                                                   64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                               (65536, Random)  \
#                                                                  spot.channel
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              4             regionprofile
#                                                   8             regionprofile
#                                                   16            regionprofile
#                                                   32            regionprofile
#                                                   64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'comm', 'type': 'function'}              4                      None
#                                                   8             regionprofile
#                                                   16            regionprofile
#                                                   32            regionprofile
#                                                   64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'comm_large', 'type': 'function'}        4                      None
#                                                   8             regionprofile
#                                                   16            regionprofile
#                                                   32            regionprofile
#                                                   64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'comm_small', 'type': 'function'}        4                      None
#                                                   8             regionprofile
#                                                   16            regionprofile
#                                                   32            regionprofile
#                                                   64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'correctness_check', 'type': 'function'} 4                      None
#                                                   8             regionprofile
#                                                   16            regionprofile
#                                                   32            regionprofile
#                                                   64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'data_init', 'type': 'function'}         4             regionprofile
#                                                   8             regionprofile
#                                                   16            regionprofile
#                                                   32            regionprofile
#                                                   64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
#
#                                                                                  \
#                                                               Avg GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              4                    0.001004
#                                                   8                    0.003512
#                                                   16                   0.000853
#                                                   32                   0.001143
#                                                   64                   0.001036
#                                                   128                  0.000883
#                                                   256                  0.000829
#                                                   512                  0.001087
#                                                   1024                 0.001090
# {'name': 'comm', 'type': 'function'}              4                         NaN
#                                                   8                    0.000054
#                                                   16                   0.000050
#                                                   32                   0.000052
#                                                   64                   0.000052
#                                                   128                  0.000051
#                                                   256                  0.000050
#                                                   512                  0.000053
#                                                   1024                 0.000052
# {'name': 'comm_large', 'type': 'function'}        4                         NaN
#                                                   8                    0.000054
#                                                   16                   0.000050
#                                                   32                   0.000052
#                                                   64                   0.000052
#                                                   128                  0.000051
#                                                   256                  0.000050
#                                                   512                  0.000053
#                                                   1024                 0.000052
# {'name': 'comm_small', 'type': 'function'}        4                         NaN
#                                                   8                         NaN
#                                                   16                        NaN
#                                                   32                        NaN
#                                                   64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'correctness_check', 'type': 'function'} 4                         NaN
#                                                   8                         NaN
#                                                   16                        NaN
#                                                   32                        NaN
#                                                   64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         4                         NaN
#                                                   8                         NaN
#                                                   16                        NaN
#                                                   32                        NaN
#                                                   64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                               (65536, Reversesorted)  \
#                                                                         spot.channel
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              4                    regionprofile
#                                                   8                    regionprofile
#                                                   16                   regionprofile
#                                                   32                   regionprofile
#                                                   64                   regionprofile
#                                                   128                  regionprofile
#                                                   256                  regionprofile
#                                                   512                  regionprofile
#                                                   1024                 regionprofile
# {'name': 'comm', 'type': 'function'}              4                    regionprofile
#                                                   8                    regionprofile
#                                                   16                   regionprofile
#                                                   32                   regionprofile
#                                                   64                   regionprofile
#                                                   128                  regionprofile
#                                                   256                  regionprofile
#                                                   512                  regionprofile
#                                                   1024                 regionprofile
# {'name': 'comm_large', 'type': 'function'}        4                    regionprofile
#                                                   8                    regionprofile
#                                                   16                   regionprofile
#                                                   32                   regionprofile
#                                                   64                   regionprofile
#                                                   128                  regionprofile
#                                                   256                  regionprofile
#                                                   512                  regionprofile
#                                                   1024                 regionprofile
# {'name': 'comm_small', 'type': 'function'}        4                    regionprofile
#                                                   8                    regionprofile
#                                                   16                   regionprofile
#                                                   32                   regionprofile
#                                                   64                   regionprofile
#                                                   128                  regionprofile
#                                                   256                  regionprofile
#                                                   512                  regionprofile
#                                                   1024                 regionprofile
# {'name': 'correctness_check', 'type': 'function'} 4                    regionprofile
#                                                   8                    regionprofile
#                                                   16                   regionprofile
#                                                   32                   regionprofile
#                                                   64                   regionprofile
#                                                   128                  regionprofile
#                                                   256                  regionprofile
#                                                   512                  regionprofile
#                                                   1024                 regionprofile
# {'name': 'data_init', 'type': 'function'}         4                    regionprofile
#                                                   8                    regionprofile
#                                                   16                   regionprofile
#                                                   32                   regionprofile
#                                                   64                   regionprofile
#                                                   128                  regionprofile
#                                                   256                  regionprofile
#                                                   512                  regionprofile
#                                                   1024                 regionprofile
#
#                                                                                  \
#                                                               Avg GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              4                    0.000868
#                                                   8                    0.000971
#                                                   16                   0.000866
#                                                   32                   0.000875
#                                                   64                   0.000901
#                                                   128                  0.000930
#                                                   256                  0.001089
#                                                   512                  0.000916
#                                                   1024                 0.000901
# {'name': 'comm', 'type': 'function'}              4                    0.000050
#                                                   8                    0.000051
#                                                   16                   0.000050
#                                                   32                   0.000050
#                                                   64                   0.000050
#                                                   128                  0.000051
#                                                   256                  0.000053
#                                                   512                  0.000051
#                                                   1024                 0.000050
# {'name': 'comm_large', 'type': 'function'}        4                    0.000050
#                                                   8                    0.000051
#                                                   16                   0.000050
#                                                   32                   0.000050
#                                                   64                   0.000050
#                                                   128                  0.000051
#                                                   256                  0.000053
#                                                   512                  0.000051
#                                                   1024                 0.000050
# {'name': 'comm_small', 'type': 'function'}        4                         NaN
#                                                   8                         NaN
#                                                   16                        NaN
#                                                   32                        NaN
#                                                   64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'correctness_check', 'type': 'function'} 4                         NaN
#                                                   8                         NaN
#                                                   16                        NaN
#                                                   32                        NaN
#                                                   64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         4                         NaN
#                                                   8                         NaN
#                                                   16                        NaN
#                                                   32                        NaN
#                                                   64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                               (65536, Sorted)  \
#                                                                  spot.channel
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              4             regionprofile
#                                                   8             regionprofile
#                                                   16            regionprofile
#                                                   32            regionprofile
#                                                   64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'comm', 'type': 'function'}              4             regionprofile
#                                                   8             regionprofile
#                                                   16            regionprofile
#                                                   32            regionprofile
#                                                   64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'comm_large', 'type': 'function'}        4             regionprofile
#                                                   8             regionprofile
#                                                   16            regionprofile
#                                                   32            regionprofile
#                                                   64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'comm_small', 'type': 'function'}        4             regionprofile
#                                                   8             regionprofile
#                                                   16            regionprofile
#                                                   32            regionprofile
#                                                   64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'correctness_check', 'type': 'function'} 4             regionprofile
#                                                   8             regionprofile
#                                                   16            regionprofile
#                                                   32            regionprofile
#                                                   64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
# {'name': 'data_init', 'type': 'function'}         4             regionprofile
#                                                   8             regionprofile
#                                                   16            regionprofile
#                                                   32            regionprofile
#                                                   64            regionprofile
#                                                   128           regionprofile
#                                                   256           regionprofile
#                                                   512           regionprofile
#                                                   1024          regionprofile
#
#                                                                                  \
#                                                               Avg GPU time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              4                    0.000650
#                                                   8                    0.001139
#                                                   16                   0.001107
#                                                   32                   0.000876
#                                                   64                   0.001149
#                                                   128                  0.001139
#                                                   256                  0.001095
#                                                   512                  0.000889
#                                                   1024                 0.000899
# {'name': 'comm', 'type': 'function'}              4                    0.000048
#                                                   8                    0.000052
#                                                   16                   0.000052
#                                                   32                   0.000050
#                                                   64                   0.000053
#                                                   128                  0.000053
#                                                   256                  0.000053
#                                                   512                  0.000051
#                                                   1024                 0.000051
# {'name': 'comm_large', 'type': 'function'}        4                    0.000048
#                                                   8                    0.000052
#                                                   16                   0.000052
#                                                   32                   0.000050
#                                                   64                   0.000053
#                                                   128                  0.000053
#                                                   256                  0.000053
#                                                   512                  0.000051
#                                                   1024                 0.000051
# {'name': 'comm_small', 'type': 'function'}        4                         NaN
#                                                   8                         NaN
#                                                   16                        NaN
#                                                   32                        NaN
#                                                   64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'correctness_check', 'type': 'function'} 4                         NaN
#                                                   8                         NaN
#                                                   16                        NaN
#                                                   32                        NaN
#                                                   64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
# {'name': 'data_init', 'type': 'function'}         4                         NaN
#                                                   8                         NaN
#                                                   16                        NaN
#                                                   32                        NaN
#                                                   64                        NaN
#                                                   128                       NaN
#                                                   256                       NaN
#                                                   512                       NaN
#                                                   1024                      NaN
#
#                                                                             name
#
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              4                         main
#                                                   8                         main
#                                                   16                        main
#                                                   32                        main
#                                                   64                        main
#                                                   128                       main
#                                                   256                       main
#                                                   512                       main
#                                                   1024                      main
# {'name': 'comm', 'type': 'function'}              4                         comm
#                                                   8                         comm
#                                                   16                        comm
#                                                   32                        comm
#                                                   64                        comm
#                                                   128                       comm
#                                                   256                       comm
#                                                   512                       comm
#                                                   1024                      comm
# {'name': 'comm_large', 'type': 'function'}        4                   comm_large
#                                                   8                   comm_large
#                                                   16                  comm_large
#                                                   32                  comm_large
#                                                   64                  comm_large
#                                                   128                 comm_large
#                                                   256                 comm_large
#                                                   512                 comm_large
#                                                   1024                comm_large
# {'name': 'comm_small', 'type': 'function'}        4                   comm_small
#                                                   8                   comm_small
#                                                   16                  comm_small
#                                                   32                  comm_small
#                                                   64                  comm_small
#                                                   128                 comm_small
#                                                   256                 comm_small
#                                                   512                 comm_small
#                                                   1024                comm_small
# {'name': 'correctness_check', 'type': 'function'} 4            correctness_check
#                                                   8            correctness_check
#                                                   16           correctness_check
#                                                   32           correctness_check
#                                                   64           correctness_check
#                                                   128          correctness_check
#                                                   256          correctness_check
#                                                   512          correctness_check
#                                                   1024         correctness_check
# {'name': 'data_init', 'type': 'function'}         4                    data_init
#                                                   8                    data_init
#                                                   16                   data_init
#                                                   32                   data_init
#                                                   64                   data_init
#                                                   128                  data_init
#                                                   256                  data_init
#                                                   512                  data_init
#                                                   1024                 data_init

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", "")], axis=1)
# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

# %% [raw]
# ctk.dataframe

# %%
# Define common variables
function_names = set(ctk.dataframe.index.get_level_values("name"))
procs = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
matrix_sizes = sorted(ctk.dataframe.columns.tolist())

# %%
ctk.dataframe.loc["main"]
# Out:
#             (65536, 1%perturbed)                   (65536, Random)  \
#                     spot.channel Avg GPU time/rank    spot.channel
# num_threads
# 4                  regionprofile          0.001140   regionprofile
# 8                  regionprofile          0.001007   regionprofile
# 16                 regionprofile          0.000976   regionprofile
# 32                 regionprofile          0.001160   regionprofile
# 64                 regionprofile          0.000869   regionprofile
# 128                regionprofile          0.000893   regionprofile
# 256                regionprofile          0.001095   regionprofile
# 512                regionprofile          0.001082   regionprofile
# 1024               regionprofile          0.000837   regionprofile
#
#                               (65536, Reversesorted)                    \
#             Avg GPU time/rank           spot.channel Avg GPU time/rank
# num_threads
# 4                    0.001004          regionprofile          0.000868
# 8                    0.003512          regionprofile          0.000971
# 16                   0.000853          regionprofile          0.000866
# 32                   0.001143          regionprofile          0.000875
# 64                   0.001036          regionprofile          0.000901
# 128                  0.000883          regionprofile          0.000930
# 256                  0.000829          regionprofile          0.001089
# 512                  0.001087          regionprofile          0.000916
# 1024                 0.001090          regionprofile          0.000901
#
#             (65536, Sorted)
#                spot.channel Avg GPU time/rank
# num_threads
# 4             regionprofile          0.000650
# 8             regionprofile          0.001139
# 16            regionprofile          0.001107
# 32            regionprofile          0.000876
# 64            regionprofile          0.001149
# 128           regionprofile          0.001139
# 256           regionprofile          0.001095
# 512           regionprofile          0.000889
# 1024          regionprofile          0.000899

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %%
for name in function_names:
    plot_pandas(
        df=ctk.dataframe.loc[name],
        title="Sample Sort | Strong Scaling | " + name,
        xlabel="Number of Threads",
        ylabel="Time (seconds)",
        # set to False 
        loglog=False
    )

# %%
        temp_df = ctk.dataframe[[col for col in ctk.dataframe.columns if col[0][0] == 65536 and col[1] == "Avg GPU time/rank"]].loc[name]
        temp_df = temp_df.iloc[0]/temp_df

# %%
# how to get input_sizes?
# speed up
input_sizes = set(tk.metadata["InputSize"])
for name in function_names:
    for size in input_sizes:
        temp_df = ctk.dataframe[[col for col in ctk.dataframe.columns if col[0][0] == 65536 and col[1] == "Avg GPU time/rank"]].loc[name]
        temp_df = temp_df.iloc[0]/temp_df

        plot_pandas (
            title = "Speed Up | " + name,
            xlabel = "Threads",
            ylabel = "Time (seconds)",
            # True or False? 
            loglog=False,
            df = temp_df
        )
