# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
# Comment out appropriate portion
#tk = th.Thicket.from_caliperreader(glob("cali_files/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/Random/Strong_Scaling_MPI/*.cali"))
tk = th.Thicket.from_caliperreader(glob("MPI-StrongScaling/*.cali"))
# tk = th.Thicket.from_caliperreader(glob("cali_files/MPI_Files/16777216_Strong/*.cali"))

# %%
# Performance data
tk.dataframe
tk.dataframe = tk.dataframe.drop([('Min time/rank'),('Max time/rank'),('Total time'), ('Variance time/rank'), ('nid')], axis=1)

# %%
tk.metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 241713974            2.11.0-dev              32
# 351069754            2.11.0-dev             512
# 430684384            2.11.0-dev               2
# 475847497            2.11.0-dev              16
# 584878418            2.11.0-dev            1024
# 624524346            2.11.0-dev            1024
# 756117376            2.11.0-dev               4
# 786832380            2.11.0-dev              64
# 1205482304           2.11.0-dev              32
# 1244465358           2.11.0-dev               4
# 1267780920           2.11.0-dev              16
# 1728896774           2.11.0-dev               8
# 1795148652           2.11.0-dev             512
# 1798306904           2.11.0-dev              64
# 1922445826           2.11.0-dev               2
# 2186813253           2.11.0-dev             512
# 2250284016           2.11.0-dev             128
# 2382301908           2.11.0-dev               8
# 2408612335           2.11.0-dev               8
# 2611300518           2.11.0-dev               2
# 2678853624           2.11.0-dev             128
# 2768572819           2.11.0-dev              64
# 2990560484           2.11.0-dev             256
# 3005267820           2.11.0-dev             512
# 3051594543           2.11.0-dev             256
# 3220018269           2.11.0-dev             256
# 3361445555           2.11.0-dev              16
# 3682944100           2.11.0-dev             128
# 3738816479           2.11.0-dev              32
# 4071677804           2.11.0-dev              32
# 4074948936           2.11.0-dev               4
# 4239269081           2.11.0-dev               8
#
#                                                  spot.metrics  \
# profile
# 241713974   min#inclusive#sum#time.duration,max#inclusive#...
# 351069754   min#inclusive#sum#time.duration,max#inclusive#...
# 430684384   min#inclusive#sum#time.duration,max#inclusive#...
# 475847497   min#inclusive#sum#time.duration,max#inclusive#...
# 584878418   min#inclusive#sum#time.duration,max#inclusive#...
# 624524346   min#inclusive#sum#time.duration,max#inclusive#...
# 756117376   min#inclusive#sum#time.duration,max#inclusive#...
# 786832380   min#inclusive#sum#time.duration,max#inclusive#...
# 1205482304  min#inclusive#sum#time.duration,max#inclusive#...
# 1244465358  min#inclusive#sum#time.duration,max#inclusive#...
# 1267780920  min#inclusive#sum#time.duration,max#inclusive#...
# 1728896774  min#inclusive#sum#time.duration,max#inclusive#...
# 1795148652  min#inclusive#sum#time.duration,max#inclusive#...
# 1798306904  min#inclusive#sum#time.duration,max#inclusive#...
# 1922445826  min#inclusive#sum#time.duration,max#inclusive#...
# 2186813253  min#inclusive#sum#time.duration,max#inclusive#...
# 2250284016  min#inclusive#sum#time.duration,max#inclusive#...
# 2382301908  min#inclusive#sum#time.duration,max#inclusive#...
# 2408612335  min#inclusive#sum#time.duration,max#inclusive#...
# 2611300518  min#inclusive#sum#time.duration,max#inclusive#...
# 2678853624  min#inclusive#sum#time.duration,max#inclusive#...
# 2768572819  min#inclusive#sum#time.duration,max#inclusive#...
# 2990560484  min#inclusive#sum#time.duration,max#inclusive#...
# 3005267820  min#inclusive#sum#time.duration,max#inclusive#...
# 3051594543  min#inclusive#sum#time.duration,max#inclusive#...
# 3220018269  min#inclusive#sum#time.duration,max#inclusive#...
# 3361445555  min#inclusive#sum#time.duration,max#inclusive#...
# 3682944100  min#inclusive#sum#time.duration,max#inclusive#...
# 3738816479  min#inclusive#sum#time.duration,max#inclusive#...
# 4071677804  min#inclusive#sum#time.duration,max#inclusive#...
# 4074948936  min#inclusive#sum#time.duration,max#inclusive#...
# 4239269081  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 241713974                                             2
# 351069754                                             2
# 430684384                                             2
# 475847497                                             2
# 584878418                                             2
# 624524346                                             2
# 756117376                                             2
# 786832380                                             2
# 1205482304                                            2
# 1244465358                                            2
# 1267780920                                            2
# 1728896774                                            2
# 1795148652                                            2
# 1798306904                                            2
# 1922445826                                            2
# 2186813253                                            2
# 2250284016                                            2
# 2382301908                                            2
# 2408612335                                            2
# 2611300518                                            2
# 2678853624                                            2
# 2768572819                                            2
# 2990560484                                            2
# 3005267820                                            2
# 3051594543                                            2
# 3220018269                                            2
# 3361445555                                            2
# 3682944100                                            2
# 3738816479                                            2
# 4071677804                                            2
# 4074948936                                            2
# 4239269081                                            2
#
#                         spot.options  spot.channels cali.channel  \
# profile
# 241713974   time.variance,node.order  regionprofile         spot
# 351069754   time.variance,node.order  regionprofile         spot
# 430684384   time.variance,node.order  regionprofile         spot
# 475847497   time.variance,node.order  regionprofile         spot
# 584878418   time.variance,node.order  regionprofile         spot
# 624524346   time.variance,node.order  regionprofile         spot
# 756117376   time.variance,node.order  regionprofile         spot
# 786832380   time.variance,node.order  regionprofile         spot
# 1205482304  time.variance,node.order  regionprofile         spot
# 1244465358  time.variance,node.order  regionprofile         spot
# 1267780920  time.variance,node.order  regionprofile         spot
# 1728896774  time.variance,node.order  regionprofile         spot
# 1795148652  time.variance,node.order  regionprofile         spot
# 1798306904  time.variance,node.order  regionprofile         spot
# 1922445826  time.variance,node.order  regionprofile         spot
# 2186813253  time.variance,node.order  regionprofile         spot
# 2250284016  time.variance,node.order  regionprofile         spot
# 2382301908  time.variance,node.order  regionprofile         spot
# 2408612335  time.variance,node.order  regionprofile         spot
# 2611300518  time.variance,node.order  regionprofile         spot
# 2678853624  time.variance,node.order  regionprofile         spot
# 2768572819  time.variance,node.order  regionprofile         spot
# 2990560484  time.variance,node.order  regionprofile         spot
# 3005267820  time.variance,node.order  regionprofile         spot
# 3051594543  time.variance,node.order  regionprofile         spot
# 3220018269  time.variance,node.order  regionprofile         spot
# 3361445555  time.variance,node.order  regionprofile         spot
# 3682944100  time.variance,node.order  regionprofile         spot
# 3738816479  time.variance,node.order  regionprofile         spot
# 4071677804  time.variance,node.order  regionprofile         spot
# 4074948936  time.variance,node.order  regionprofile         spot
# 4239269081  time.variance,node.order  regionprofile         spot
#
#            spot:node.order        spot:output spot:time.variance  launchdate  \
# profile
# 241713974             true    p32-a65536.cali               true  1702017610
# 351069754             true   p512-a65536.cali               true  1702018229
# 430684384             true     p2-a65536.cali               true  1702017769
# 475847497             true    p16-a65536.cali               true  1702017610
# 584878418             true  p1024-a65536.cali               true  1702010779
# 624524346             true  p1024-a65536.cali               true  1702018059
# 756117376             true     p4-a65536.cali               true  1702013944
# 786832380             true    p64-a65536.cali               true  1702017849
# 1205482304            true    p32-a65536.cali               true  1702013749
# 1244465358            true     p4-a65536.cali               true  1702016349
# 1267780920            true    p16-a65536.cali               true  1702014090
# 1728896774            true     p8-a65536.cali               true  1702014076
# 1795148652            true   p512-a65536.cali               true  1702010681
# 1798306904            true    p64-a65536.cali               true  1702016364
# 1922445826            true     p2-a65536.cali               true  1702009634
# 2186813253            true   p512-a65536.cali               true  1702016608
# 2250284016            true   p128-a65536.cali               true  1702013762
# 2382301908            true     p8-a65536.cali               true  1702009921
# 2408612335            true     p8-a65536.cali               true  1702016390
# 2611300518            true     p2-a65536.cali               true  1702013932
# 2678853624            true   p128-a65536.cali               true  1702010528
# 2768572819            true    p64-a65536.cali               true  1702010420
# 2990560484            true   p256-a65536.cali               true  1702010581
# 3005267820            true   p512-a65536.cali               true  1702014449
# 3051594543            true   p256-a65536.cali               true  1702018049
# 3220018269            true   p256-a65536.cali               true  1702016588
# 3361445555            true    p16-a65536.cali               true  1702010040
# 3682944100            true   p128-a65536.cali               true  1702018229
# 3738816479            true    p32-a65536.cali               true  1702010083
# 4071677804            true    p32-a65536.cali               true  1702016365
# 4074948936            true     p4-a65536.cali               true  1702010099
# 4239269081            true     p8-a65536.cali               true  1702017844
#
#                                                     libraries  \
# profile
# 241713974   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 351069754   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 430684384   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 475847497   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 584878418   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 624524346   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 756117376   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 786832380   [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1205482304  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1244465358  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1267780920  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1728896774  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1795148652  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1798306904  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1922445826  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2186813253  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2250284016  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2382301908  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2408612335  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2611300518  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2678853624  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2768572819  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2990560484  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3005267820  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3051594543  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3220018269  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3361445555  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3682944100  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3738816479  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4071677804  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4074948936  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4239269081  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                     cmdline cluster   Algorithm ProgrammingModel Datatype  \
# profile
# 241713974   [./sort, 65536]       c  SampleSort              MPI    float
# 351069754   [./sort, 65536]       c  SampleSort              MPI    float
# 430684384   [./sort, 65536]       c  SampleSort              MPI    float
# 475847497   [./sort, 65536]       c  SampleSort              MPI    float
# 584878418   [./sort, 65536]       c  SampleSort              MPI    float
# 624524346   [./sort, 65536]       c  SampleSort              MPI    float
# 756117376   [./sort, 65536]       c  SampleSort              MPI    float
# 786832380   [./sort, 65536]       c  SampleSort              MPI    float
# 1205482304  [./sort, 65536]       c  SampleSort              MPI    float
# 1244465358  [./sort, 65536]       c  SampleSort              MPI    float
# 1267780920  [./sort, 65536]       c  SampleSort              MPI    float
# 1728896774  [./sort, 65536]       c  SampleSort              MPI    float
# 1795148652  [./sort, 65536]       c  SampleSort              MPI    float
# 1798306904  [./sort, 65536]       c  SampleSort              MPI    float
# 1922445826  [./sort, 65536]       c  SampleSort              MPI    float
# 2186813253  [./sort, 65536]       c  SampleSort              MPI    float
# 2250284016  [./sort, 65536]       c  SampleSort              MPI    float
# 2382301908  [./sort, 65536]       c  SampleSort              MPI    float
# 2408612335  [./sort, 65536]       c  SampleSort              MPI    float
# 2611300518  [./sort, 65536]       c  SampleSort              MPI    float
# 2678853624  [./sort, 65536]       c  SampleSort              MPI    float
# 2768572819  [./sort, 65536]       c  SampleSort              MPI    float
# 2990560484  [./sort, 65536]       c  SampleSort              MPI    float
# 3005267820  [./sort, 65536]       c  SampleSort              MPI    float
# 3051594543  [./sort, 65536]       c  SampleSort              MPI    float
# 3220018269  [./sort, 65536]       c  SampleSort              MPI    float
# 3361445555  [./sort, 65536]       c  SampleSort              MPI    float
# 3682944100  [./sort, 65536]       c  SampleSort              MPI    float
# 3738816479  [./sort, 65536]       c  SampleSort              MPI    float
# 4071677804  [./sort, 65536]       c  SampleSort              MPI    float
# 4074948936  [./sort, 65536]       c  SampleSort              MPI    float
# 4239269081  [./sort, 65536]       c  SampleSort              MPI    float
#
#             SizeOfDatatype  InputSize      InputType  num_procs  group_num  \
# profile
# 241713974                4      65536  Reversesorted         32         24
# 351069754                4      65536  Reversesorted        512         24
# 430684384                4      65536  Reversesorted          2         24
# 475847497                4      65536  Reversesorted         16         24
# 584878418                4      65536         Random       1024         24
# 624524346                4      65536  Reversesorted       1024         24
# 756117376                4      65536    1%perturbed          4         24
# 786832380                4      65536  Reversesorted         64         24
# 1205482304               4      65536    1%perturbed         32         24
# 1244465358               4      65536         Sorted          4         24
# 1267780920               4      65536    1%perturbed         16         24
# 1728896774               4      65536    1%perturbed          8         24
# 1795148652               4      65536         Random        512         24
# 1798306904               4      65536         Sorted         64         24
# 1922445826               4      65536         Random          2         24
# 2186813253               4      65536         Sorted        512         24
# 2250284016               4      65536    1%perturbed        128         24
# 2382301908               4      65536         Random          8         24
# 2408612335               4      65536         Sorted          8         24
# 2611300518               4      65536    1%perturbed          2         24
# 2678853624               4      65536         Random        128         24
# 2768572819               4      65536         Random         64         24
# 2990560484               4      65536         Random        256         24
# 3005267820               4      65536    1%perturbed        512         24
# 3051594543               4      65536  Reversesorted        256         24
# 3220018269               4      65536         Sorted        256         24
# 3361445555               4      65536         Random         16         24
# 3682944100               4      65536  Reversesorted        128         24
# 3738816479               4      65536         Random         32         24
# 4071677804               4      65536         Sorted         32         24
# 4074948936               4      65536         Random          4         24
# 4239269081               4      65536  Reversesorted          8         24
#
#                            implementation_source
# profile
# 241713974   Mix of Handwritted and AI and Online
# 351069754   Mix of Handwritted and AI and Online
# 430684384   Mix of Handwritted and AI and Online
# 475847497   Mix of Handwritted and AI and Online
# 584878418   Mix of Handwritted and AI and Online
# 624524346   Mix of Handwritted and AI and Online
# 756117376   Mix of Handwritted and AI and Online
# 786832380   Mix of Handwritted and AI and Online
# 1205482304  Mix of Handwritted and AI and Online
# 1244465358  Mix of Handwritted and AI and Online
# 1267780920  Mix of Handwritted and AI and Online
# 1728896774  Mix of Handwritted and AI and Online
# 1795148652  Mix of Handwritted and AI and Online
# 1798306904  Mix of Handwritted and AI and Online
# 1922445826  Mix of Handwritted and AI and Online
# 2186813253  Mix of Handwritted and AI and Online
# 2250284016  Mix of Handwritted and AI and Online
# 2382301908  Mix of Handwritted and AI and Online
# 2408612335  Mix of Handwritted and AI and Online
# 2611300518  Mix of Handwritted and AI and Online
# 2678853624  Mix of Handwritted and AI and Online
# 2768572819  Mix of Handwritted and AI and Online
# 2990560484  Mix of Handwritted and AI and Online
# 3005267820  Mix of Handwritted and AI and Online
# 3051594543  Mix of Handwritted and AI and Online
# 3220018269  Mix of Handwritted and AI and Online
# 3361445555  Mix of Handwritted and AI and Online
# 3682944100  Mix of Handwritted and AI and Online
# 3738816479  Mix of Handwritted and AI and Online
# 4071677804  Mix of Handwritted and AI and Online
# 4074948936  Mix of Handwritted and AI and Online
# 4239269081  Mix of Handwritted and AI and Online

# %%
tk.metadata
tk.statsframe.dataframe["time"] = 1
print(tk.tree())
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.1
#
# 1.000 main
# ├─ 1.000 comp_large
# ├─ 1.000 comp_small
# ├─ 1.000 data_init
# ├─ 1.000 gatherv
# ├─ 1.000 scatter
# └─ 1.000 scatterv
#
# Legend (Metric: time Min: 1.00 Max: 1.00)
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
# █ 1.00 - 1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph

# %%
# strong
gb = tk.groupby([("InputSize"), ("InputType")])
# weak
# gb = tk.groupby([("InputType")])
# Out:
# 4  thickets created...
# {(65536, '1%perturbed'): <thicket.thicket.Thicket object at 0x17d67c710>, (65536, 'Random'): <thicket.thicket.Thicket object at 0x2813f1890>, (65536, 'Reversesorted'): <thicket.thicket.Thicket object at 0x281667d90>, (65536, 'Sorted'): <thicket.thicket.Thicket object at 0x28164b690>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_procs"
)

# %%
ctk.dataframe
# Out:
#                                                      (65536, 1%perturbed)  \
#                                                              spot.channel
# node                                       num_procs
# {'name': 'main', 'type': 'function'}       2                regionprofile
#                                            4                regionprofile
#                                            8                regionprofile
#                                            16               regionprofile
#                                            32               regionprofile
#                                            64                         NaN
#                                            128              regionprofile
#                                            256                        NaN
#                                            512              regionprofile
#                                            1024                       NaN
# {'name': 'comp_large', 'type': 'function'} 2                regionprofile
#                                            4                regionprofile
#                                            8                regionprofile
#                                            16               regionprofile
#                                            32               regionprofile
#                                            64                         NaN
#                                            128              regionprofile
#                                            256                        NaN
#                                            512              regionprofile
#                                            1024                       NaN
# {'name': 'comp_small', 'type': 'function'} 2                regionprofile
#                                            4                regionprofile
#                                            8                regionprofile
#                                            16               regionprofile
#                                            32               regionprofile
#                                            64                         NaN
#                                            128              regionprofile
#                                            256                        NaN
#                                            512              regionprofile
#                                            1024                       NaN
# {'name': 'data_init', 'type': 'function'}  2                regionprofile
#                                            4                regionprofile
#                                            8                regionprofile
#                                            16               regionprofile
#                                            32               regionprofile
#                                            64                         NaN
#                                            128              regionprofile
#                                            256                        NaN
#                                            512              regionprofile
#                                            1024                       NaN
# {'name': 'gatherv', 'type': 'function'}    2                regionprofile
#                                            4                regionprofile
#                                            8                regionprofile
#                                            16               regionprofile
#                                            32               regionprofile
#                                            64                         NaN
#                                            128              regionprofile
#                                            256                        NaN
#                                            512              regionprofile
#                                            1024                       NaN
# {'name': 'scatter', 'type': 'function'}    2                regionprofile
#                                            4                regionprofile
#                                            8                regionprofile
#                                            16               regionprofile
#                                            32               regionprofile
#                                            64                         NaN
#                                            128              regionprofile
#                                            256                        NaN
#                                            512              regionprofile
#                                            1024                       NaN
# {'name': 'scatterv', 'type': 'function'}   2                regionprofile
#                                            4                regionprofile
#                                            8                regionprofile
#                                            16               regionprofile
#                                            32               regionprofile
#                                            64                         NaN
#                                            128              regionprofile
#                                            256                        NaN
#                                            512              regionprofile
#                                            1024                       NaN
#
#                                                                     \
#                                                      Avg time/rank
# node                                       num_procs
# {'name': 'main', 'type': 'function'}       2              0.602778
#                                            4              0.365818
#                                            8              0.498856
#                                            16             0.782256
#                                            32             1.649574
#                                            64                  NaN
#                                            128            1.701019
#                                            256                 NaN
#                                            512            2.416676
#                                            1024                NaN
# {'name': 'comp_large', 'type': 'function'} 2              0.001493
#                                            4              0.002132
#                                            8              0.002477
#                                            16             0.003238
#                                            32             0.004348
#                                            64                  NaN
#                                            128            0.011139
#                                            256                 NaN
#                                            512            0.038614
#                                            1024                NaN
# {'name': 'comp_small', 'type': 'function'} 2              0.000006
#                                            4              0.000006
#                                            8              0.000007
#                                            16             0.000006
#                                            32             0.000009
#                                            64                  NaN
#                                            128            0.000006
#                                            256                 NaN
#                                            512            0.000010
#                                            1024                NaN
# {'name': 'data_init', 'type': 'function'}  2              0.001104
#                                            4              0.000647
#                                            8              0.000530
#                                            16             0.000327
#                                            32             0.000184
#                                            64                  NaN
#                                            128            0.000123
#                                            256                 NaN
#                                            512            0.000105
#                                            1024                NaN
# {'name': 'gatherv', 'type': 'function'}    2              0.001441
#                                            4              0.001489
#                                            8              0.001859
#                                            16             0.000592
#                                            32             0.001518
#                                            64                  NaN
#                                            128            0.007457
#                                            256                 NaN
#                                            512            0.008912
#                                            1024                NaN
# {'name': 'scatter', 'type': 'function'}    2              0.001256
#                                            4              0.001912
#                                            8              0.004551
#                                            16             0.006190
#                                            32             0.038099
#                                            64                  NaN
#                                            128            0.020670
#                                            256                 NaN
#                                            512            0.158563
#                                            1024                NaN
# {'name': 'scatterv', 'type': 'function'}   2              0.001424
#                                            4              0.001950
#                                            8              0.002886
#                                            16             0.003290
#                                            32             0.000274
#                                            64                  NaN
#                                            128            0.016041
#                                            256                 NaN
#                                            512            0.041576
#                                            1024                NaN
#
#                                                      (65536, Random)  \
#                                                         spot.channel
# node                                       num_procs
# {'name': 'main', 'type': 'function'}       2           regionprofile
#                                            4           regionprofile
#                                            8           regionprofile
#                                            16          regionprofile
#                                            32          regionprofile
#                                            64          regionprofile
#                                            128         regionprofile
#                                            256         regionprofile
#                                            512         regionprofile
#                                            1024        regionprofile
# {'name': 'comp_large', 'type': 'function'} 2           regionprofile
#                                            4           regionprofile
#                                            8           regionprofile
#                                            16          regionprofile
#                                            32          regionprofile
#                                            64          regionprofile
#                                            128         regionprofile
#                                            256         regionprofile
#                                            512         regionprofile
#                                            1024        regionprofile
# {'name': 'comp_small', 'type': 'function'} 2           regionprofile
#                                            4           regionprofile
#                                            8           regionprofile
#                                            16          regionprofile
#                                            32          regionprofile
#                                            64          regionprofile
#                                            128         regionprofile
#                                            256         regionprofile
#                                            512         regionprofile
#                                            1024        regionprofile
# {'name': 'data_init', 'type': 'function'}  2           regionprofile
#                                            4           regionprofile
#                                            8           regionprofile
#                                            16          regionprofile
#                                            32          regionprofile
#                                            64          regionprofile
#                                            128         regionprofile
#                                            256         regionprofile
#                                            512         regionprofile
#                                            1024        regionprofile
# {'name': 'gatherv', 'type': 'function'}    2           regionprofile
#                                            4           regionprofile
#                                            8           regionprofile
#                                            16          regionprofile
#                                            32          regionprofile
#                                            64          regionprofile
#                                            128         regionprofile
#                                            256         regionprofile
#                                            512         regionprofile
#                                            1024        regionprofile
# {'name': 'scatter', 'type': 'function'}    2           regionprofile
#                                            4           regionprofile
#                                            8           regionprofile
#                                            16          regionprofile
#                                            32          regionprofile
#                                            64          regionprofile
#                                            128         regionprofile
#                                            256         regionprofile
#                                            512         regionprofile
#                                            1024        regionprofile
# {'name': 'scatterv', 'type': 'function'}   2           regionprofile
#                                            4           regionprofile
#                                            8           regionprofile
#                                            16          regionprofile
#                                            32          regionprofile
#                                            64          regionprofile
#                                            128         regionprofile
#                                            256         regionprofile
#                                            512         regionprofile
#                                            1024        regionprofile
#
#                                                                     \
#                                                      Avg time/rank
# node                                       num_procs
# {'name': 'main', 'type': 'function'}       2              0.285798
#                                            4              0.370942
#                                            8              0.501280
#                                            16             0.769968
#                                            32             1.412826
#                                            64             1.374758
#                                            128            1.450374
#                                            256            1.767971
#                                            512            4.221315
#                                            1024           3.202585
# {'name': 'comp_large', 'type': 'function'} 2              0.001505
#                                            4              0.002137
#                                            8              0.002948
#                                            16             0.003161
#                                            32             0.004359
#                                            64             0.006634
#                                            128            0.011257
#                                            256            0.020602
#                                            512            0.077431
#                                            1024           0.075064
# {'name': 'comp_small', 'type': 'function'} 2              0.000006
#                                            4              0.000006
#                                            8              0.000007
#                                            16             0.000006
#                                            32             0.000005
#                                            64             0.000006
#                                            128            0.000013
#                                            256            0.000009
#                                            512            0.000011
#                                            1024           0.000014
# {'name': 'data_init', 'type': 'function'}  2              0.000966
#                                            4              0.000682
#                                            8              0.000440
#                                            16             0.000249
#                                            32             0.000185
#                                            64             0.000142
#                                            128            0.000120
#                                            256            0.000110
#                                            512            0.000179
#                                            1024           0.000108
# {'name': 'gatherv', 'type': 'function'}    2              0.001319
#                                            4              0.001790
#                                            8              0.001149
#                                            16             0.000642
#                                            32             0.002057
#                                            64             0.004253
#                                            128            0.004868
#                                            256            0.021216
#                                            512            0.039882
#                                            1024           0.000949
# {'name': 'scatter', 'type': 'function'}    2              0.000619
#                                            4              0.002621
#                                            8              0.003068
#                                            16             0.002813
#                                            32             0.049877
#                                            64             0.012554
#                                            128            0.018712
#                                            256            0.050145
#                                            512            0.060100
#                                            1024           0.097380
# {'name': 'scatterv', 'type': 'function'}   2              0.001539
#                                            4              0.001896
#                                            8              0.003478
#                                            16             0.003128
#                                            32             0.000221
#                                            64             0.010155
#                                            128            0.015815
#                                            256            0.040527
#                                            512            0.067303
#                                            1024           0.045753
#
#                                                      (65536, Reversesorted)  \
#                                                                spot.channel
# node                                       num_procs
# {'name': 'main', 'type': 'function'}       2                  regionprofile
#                                            4                            NaN
#                                            8                  regionprofile
#                                            16                 regionprofile
#                                            32                 regionprofile
#                                            64                 regionprofile
#                                            128                regionprofile
#                                            256                regionprofile
#                                            512                regionprofile
#                                            1024               regionprofile
# {'name': 'comp_large', 'type': 'function'} 2                  regionprofile
#                                            4                            NaN
#                                            8                  regionprofile
#                                            16                 regionprofile
#                                            32                 regionprofile
#                                            64                 regionprofile
#                                            128                regionprofile
#                                            256                regionprofile
#                                            512                regionprofile
#                                            1024               regionprofile
# {'name': 'comp_small', 'type': 'function'} 2                  regionprofile
#                                            4                            NaN
#                                            8                  regionprofile
#                                            16                 regionprofile
#                                            32                 regionprofile
#                                            64                 regionprofile
#                                            128                regionprofile
#                                            256                regionprofile
#                                            512                regionprofile
#                                            1024               regionprofile
# {'name': 'data_init', 'type': 'function'}  2                  regionprofile
#                                            4                            NaN
#                                            8                  regionprofile
#                                            16                 regionprofile
#                                            32                 regionprofile
#                                            64                 regionprofile
#                                            128                regionprofile
#                                            256                regionprofile
#                                            512                regionprofile
#                                            1024               regionprofile
# {'name': 'gatherv', 'type': 'function'}    2                  regionprofile
#                                            4                            NaN
#                                            8                  regionprofile
#                                            16                 regionprofile
#                                            32                 regionprofile
#                                            64                 regionprofile
#                                            128                regionprofile
#                                            256                regionprofile
#                                            512                regionprofile
#                                            1024               regionprofile
# {'name': 'scatter', 'type': 'function'}    2                  regionprofile
#                                            4                            NaN
#                                            8                  regionprofile
#                                            16                 regionprofile
#                                            32                 regionprofile
#                                            64                 regionprofile
#                                            128                regionprofile
#                                            256                regionprofile
#                                            512                regionprofile
#                                            1024               regionprofile
# {'name': 'scatterv', 'type': 'function'}   2                  regionprofile
#                                            4                            NaN
#                                            8                  regionprofile
#                                            16                 regionprofile
#                                            32                 regionprofile
#                                            64                 regionprofile
#                                            128                regionprofile
#                                            256                regionprofile
#                                            512                regionprofile
#                                            1024               regionprofile
#
#                                                                     \
#                                                      Avg time/rank
# node                                       num_procs
# {'name': 'main', 'type': 'function'}       2              0.587444
#                                            4                   NaN
#                                            8              0.490429
#                                            16             0.759129
#                                            32             1.413173
#                                            64             2.590944
#                                            128            1.461339
#                                            256            2.014688
#                                            512            2.641046
#                                            1024           6.481405
# {'name': 'comp_large', 'type': 'function'} 2              0.001714
#                                            4                   NaN
#                                            8              0.002444
#                                            16             0.003457
#                                            32             0.008845
#                                            64             0.010921
#                                            128            0.011181
#                                            256            0.020397
#                                            512            0.038700
#                                            1024           0.151590
# {'name': 'comp_small', 'type': 'function'} 2              0.000007
#                                            4                   NaN
#                                            8              0.000006
#                                            16             0.000006
#                                            32             0.000006
#                                            64             0.000006
#                                            128            0.000006
#                                            256            0.000010
#                                            512            0.000009
#                                            1024           0.000015
# {'name': 'data_init', 'type': 'function'}  2              0.001051
#                                            4                   NaN
#                                            8              0.000455
#                                            16             0.000293
#                                            32             0.000185
#                                            64             0.000186
#                                            128            0.000120
#                                            256            0.000121
#                                            512            0.000107
#                                            1024           0.000195
# {'name': 'gatherv', 'type': 'function'}    2              0.000976
#                                            4                   NaN
#                                            8              0.001557
#                                            16             0.002152
#                                            32             0.012401
#                                            64             0.004156
#                                            128            0.007239
#                                            256            0.008458
#                                            512            0.006018
#                                            1024           0.002028
# {'name': 'scatter', 'type': 'function'}    2              0.001779
#                                            4                   NaN
#                                            8              0.002845
#                                            16             0.004915
#                                            32             0.029142
#                                            64             0.008990
#                                            128            0.032471
#                                            256            0.053680
#                                            512            0.041276
#                                            1024           0.182441
# {'name': 'scatterv', 'type': 'function'}   2              0.001635
#                                            4                   NaN
#                                            8              0.002242
#                                            16             0.003973
#                                            32             0.000621
#                                            64             0.018928
#                                            128            0.015337
#                                            256            0.026078
#                                            512            0.022093
#                                            1024           0.113188
#
#                                                      (65536, Sorted)  \
#                                                         spot.channel
# node                                       num_procs
# {'name': 'main', 'type': 'function'}       2                     NaN
#                                            4           regionprofile
#                                            8           regionprofile
#                                            16                    NaN
#                                            32          regionprofile
#                                            64          regionprofile
#                                            128                   NaN
#                                            256         regionprofile
#                                            512         regionprofile
#                                            1024                  NaN
# {'name': 'comp_large', 'type': 'function'} 2                     NaN
#                                            4           regionprofile
#                                            8           regionprofile
#                                            16                    NaN
#                                            32          regionprofile
#                                            64          regionprofile
#                                            128                   NaN
#                                            256         regionprofile
#                                            512         regionprofile
#                                            1024                  NaN
# {'name': 'comp_small', 'type': 'function'} 2                     NaN
#                                            4           regionprofile
#                                            8           regionprofile
#                                            16                    NaN
#                                            32          regionprofile
#                                            64          regionprofile
#                                            128                   NaN
#                                            256         regionprofile
#                                            512         regionprofile
#                                            1024                  NaN
# {'name': 'data_init', 'type': 'function'}  2                     NaN
#                                            4           regionprofile
#                                            8           regionprofile
#                                            16                    NaN
#                                            32          regionprofile
#                                            64          regionprofile
#                                            128                   NaN
#                                            256         regionprofile
#                                            512         regionprofile
#                                            1024                  NaN
# {'name': 'gatherv', 'type': 'function'}    2                     NaN
#                                            4           regionprofile
#                                            8           regionprofile
#                                            16                    NaN
#                                            32          regionprofile
#                                            64          regionprofile
#                                            128                   NaN
#                                            256         regionprofile
#                                            512         regionprofile
#                                            1024                  NaN
# {'name': 'scatter', 'type': 'function'}    2                     NaN
#                                            4           regionprofile
#                                            8           regionprofile
#                                            16                    NaN
#                                            32          regionprofile
#                                            64          regionprofile
#                                            128                   NaN
#                                            256         regionprofile
#                                            512         regionprofile
#                                            1024                  NaN
# {'name': 'scatterv', 'type': 'function'}   2                     NaN
#                                            4           regionprofile
#                                            8           regionprofile
#                                            16                    NaN
#                                            32          regionprofile
#                                            64          regionprofile
#                                            128                   NaN
#                                            256         regionprofile
#                                            512         regionprofile
#                                            1024                  NaN
#
#                                                                           name
#                                                      Avg time/rank
# node                                       num_procs
# {'name': 'main', 'type': 'function'}       2                   NaN        main
#                                            4              0.371017        main
#                                            8              0.500852        main
#                                            16                  NaN        main
#                                            32             1.650441        main
#                                            64             2.644399        main
#                                            128                 NaN        main
#                                            256            1.823128        main
#                                            512            4.197349        main
#                                            1024                NaN        main
# {'name': 'comp_large', 'type': 'function'} 2                   NaN  comp_large
#                                            4              0.001760  comp_large
#                                            8              0.002718  comp_large
#                                            16                  NaN  comp_large
#                                            32             0.004665  comp_large
#                                            64             0.018148  comp_large
#                                            128                 NaN  comp_large
#                                            256            0.021184  comp_large
#                                            512            0.071065  comp_large
#                                            1024                NaN  comp_large
# {'name': 'comp_small', 'type': 'function'} 2                   NaN  comp_small
#                                            4              0.000006  comp_small
#                                            8              0.000006  comp_small
#                                            16                  NaN  comp_small
#                                            32             0.000009  comp_small
#                                            64             0.000006  comp_small
#                                            128                 NaN  comp_small
#                                            256            0.000011  comp_small
#                                            512            0.000012  comp_small
#                                            1024                NaN  comp_small
# {'name': 'data_init', 'type': 'function'}  2                   NaN   data_init
#                                            4              0.000666   data_init
#                                            8              0.000417   data_init
#                                            16                  NaN   data_init
#                                            32             0.000192   data_init
#                                            64             0.000140   data_init
#                                            128                 NaN   data_init
#                                            256            0.000120   data_init
#                                            512            0.000188   data_init
#                                            1024                NaN   data_init
# {'name': 'gatherv', 'type': 'function'}    2                   NaN     gatherv
#                                            4              0.001276     gatherv
#                                            8              0.000641     gatherv
#                                            16                  NaN     gatherv
#                                            32             0.001473     gatherv
#                                            64             0.008463     gatherv
#                                            128                 NaN     gatherv
#                                            256            0.007718     gatherv
#                                            512            0.023053     gatherv
#                                            1024                NaN     gatherv
# {'name': 'scatter', 'type': 'function'}    2                   NaN     scatter
#                                            4              0.003041     scatter
#                                            8              0.002932     scatter
#                                            16                  NaN     scatter
#                                            32             0.039892     scatter
#                                            64             0.009544     scatter
#                                            128                 NaN     scatter
#                                            256            0.037425     scatter
#                                            512            0.112848     scatter
#                                            1024                NaN     scatter
# {'name': 'scatterv', 'type': 'function'}   2                   NaN    scatterv
#                                            4              0.001730    scatterv
#                                            8              0.003816    scatterv
#                                            16                  NaN    scatterv
#                                            32             0.000254    scatterv
#                                            64             0.022204    scatterv
#                                            128                 NaN    scatterv
#                                            256            0.027547    scatterv
#                                            512            0.084214    scatterv
#                                            1024                NaN    scatterv

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", "")], axis=1)

# Rename index to remove tuple
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])

# %% [raw]
# ctk.dataframe

# %%
# Define common variables
function_names = set(ctk.dataframe.index.get_level_values("name"))
procs = sorted(list(set(ctk.dataframe.index.get_level_values("num_procs"))))
matrix_sizes = sorted(ctk.dataframe.columns.tolist())
#time = set(ctk.dataframe.index.get_level_values("Total time"))

# %%
ctk.dataframe.loc["main"]
# Out:
#           (65536, 1%perturbed)               (65536, Random)                \
#                   spot.channel Avg time/rank    spot.channel Avg time/rank
# num_procs
# 2                regionprofile      0.602778   regionprofile      0.285798
# 4                regionprofile      0.365818   regionprofile      0.370942
# 8                regionprofile      0.498856   regionprofile      0.501280
# 16               regionprofile      0.782256   regionprofile      0.769968
# 32               regionprofile      1.649574   regionprofile      1.412826
# 64                         NaN           NaN   regionprofile      1.374758
# 128              regionprofile      1.701019   regionprofile      1.450374
# 256                        NaN           NaN   regionprofile      1.767971
# 512              regionprofile      2.416676   regionprofile      4.221315
# 1024                       NaN           NaN   regionprofile      3.202585
#
#           (65536, Reversesorted)               (65536, Sorted)
#                     spot.channel Avg time/rank    spot.channel Avg time/rank
# num_procs
# 2                  regionprofile      0.587444             NaN           NaN
# 4                            NaN           NaN   regionprofile      0.371017
# 8                  regionprofile      0.490429   regionprofile      0.500852
# 16                 regionprofile      0.759129             NaN           NaN
# 32                 regionprofile      1.413173   regionprofile      1.650441
# 64                 regionprofile      2.590944   regionprofile      2.644399
# 128                regionprofile      1.461339             NaN           NaN
# 256                regionprofile      2.014688   regionprofile      1.823128
# 512                regionprofile      2.641046   regionprofile      4.197349
# 1024               regionprofile      6.481405             NaN           NaN

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %%
for name in function_names:
    plot_pandas(
        df=ctk.dataframe.loc[name],
        title="Sample Sort | Strong Scaling " + name,
        xlabel="Number of Processors",
        ylabel="Time (seconds)",
        # set to False 
        loglog=False
    )

# %%
# how to get input_sizes?
# speed up
input_sizes = set(tk.metadata["InputSize"])
for name in function_names:
    for size in input_sizes:
        temp_df = ctk.dataframe[[col for col in ctk.dataframe.columns if col[0][0] == 65536 and col[1] == "Avg time/rank"]].loc[name]
        temp_df = temp_df.iloc[0]/temp_df

        plot_pandas (
            title = "Speed Up | " + name,
            xlabel = "Threads",
            ylabel = "Time (seconds)",
            # True or False? 
            loglog=False,
            df = temp_df
        )

# %%
temp_df = ctk.dataframe[[col for col in ctk.dataframe.columns if col[0][0] == 1000 and col[1] == "Avg time/rank"]].loc[name]
temp_df.iloc[0]/temp_df
# Out:
# Empty DataFrame
# Columns: []
# Index: [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]
