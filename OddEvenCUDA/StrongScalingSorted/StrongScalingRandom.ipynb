# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
# Comment out appropriate portion
tk = th.Thicket.from_caliperreader(glob("*.cali"))

# %%
# Performance data
tk.dataframe
# Out:
#                                                               nid  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1010172828    1
#                                                   1768365132    1
#                                                   1809099769    1
#                                                   3203306122    1
#                                                   3301681376    1
#                                                   3509461676    1
# {'name': 'comm', 'type': 'function'}              1010172828    3
#                                                   1768365132    3
#                                                   1809099769    3
#                                                   3203306122    3
#                                                   3301681376    3
#                                                   3509461676    3
# {'name': 'comm_large', 'type': 'function'}        1010172828    4
#                                                   1768365132    4
#                                                   1809099769    4
#                                                   3203306122    4
#                                                   3301681376    4
#                                                   3509461676    4
# {'name': 'comm_small', 'type': 'function'}        1010172828    7
#                                                   1768365132    7
#                                                   1809099769    7
#                                                   3203306122    7
#                                                   3301681376    7
#                                                   3509461676    7
# {'name': 'comp', 'type': 'function'}              1010172828    5
#                                                   1768365132    5
#                                                   1809099769    5
#                                                   3203306122    5
#                                                   3301681376    5
#                                                   3509461676    5
# {'name': 'comp_large', 'type': 'function'}        1010172828    6
#                                                   1768365132    6
#                                                   1809099769    6
#                                                   3203306122    6
#                                                   3301681376    6
#                                                   3509461676    6
# {'name': 'correctness_check', 'type': 'function'} 1010172828    8
#                                                   1768365132    8
#                                                   1809099769    8
#                                                   3203306122    8
#                                                   3301681376    8
#                                                   3509461676    8
# {'name': 'data_init', 'type': 'function'}         1010172828    2
#                                                   1768365132    2
#                                                   1809099769    2
#                                                   3203306122    2
#                                                   3301681376    2
#                                                   3509461676    2
#
#                                                                spot.channel  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              1010172828  regionprofile
#                                                   1768365132  regionprofile
#                                                   1809099769  regionprofile
#                                                   3203306122  regionprofile
#                                                   3301681376  regionprofile
#                                                   3509461676  regionprofile
# {'name': 'comm', 'type': 'function'}              1010172828  regionprofile
#                                                   1768365132  regionprofile
#                                                   1809099769  regionprofile
#                                                   3203306122  regionprofile
#                                                   3301681376  regionprofile
#                                                   3509461676  regionprofile
# {'name': 'comm_large', 'type': 'function'}        1010172828  regionprofile
#                                                   1768365132  regionprofile
#                                                   1809099769  regionprofile
#                                                   3203306122  regionprofile
#                                                   3301681376  regionprofile
#                                                   3509461676  regionprofile
# {'name': 'comm_small', 'type': 'function'}        1010172828  regionprofile
#                                                   1768365132  regionprofile
#                                                   1809099769  regionprofile
#                                                   3203306122  regionprofile
#                                                   3301681376  regionprofile
#                                                   3509461676  regionprofile
# {'name': 'comp', 'type': 'function'}              1010172828  regionprofile
#                                                   1768365132  regionprofile
#                                                   1809099769  regionprofile
#                                                   3203306122  regionprofile
#                                                   3301681376  regionprofile
#                                                   3509461676  regionprofile
# {'name': 'comp_large', 'type': 'function'}        1010172828  regionprofile
#                                                   1768365132  regionprofile
#                                                   1809099769  regionprofile
#                                                   3203306122  regionprofile
#                                                   3301681376  regionprofile
#                                                   3509461676  regionprofile
# {'name': 'correctness_check', 'type': 'function'} 1010172828  regionprofile
#                                                   1768365132  regionprofile
#                                                   1809099769  regionprofile
#                                                   3203306122  regionprofile
#                                                   3301681376  regionprofile
#                                                   3509461676  regionprofile
# {'name': 'data_init', 'type': 'function'}         1010172828  regionprofile
#                                                   1768365132  regionprofile
#                                                   1809099769  regionprofile
#                                                   3203306122  regionprofile
#                                                   3301681376  regionprofile
#                                                   3509461676  regionprofile
#
#                                                               Min time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              
#                                                   3203306122  127.274094
#                                                   3301681376   99.395648
#                                                   3509461676  126.973342
# {'name': 'correctness_check', 'type': 'function'} 1010172828    0.000044
#                                                   1768365132    0.000042
#                                                   1809099769    0.000044
#                                                   3203306122    0.000045
#                                                   3301681376    0.000045
#                                                   3509461676    0.000044
# {'name': 'data_init', 'type': 'function'}         1010172828    0.374010
#                                                   1768365132    0.373858
#                                                   1809099769    0.373917
#                                                   3203306122    0.373936
#                                                   3301681376    0.374398
#                                                   3509461676    0.374202
#
#                                                                            name
# node                                              profile
# {'name': 'main', 'type': 'function'}              1010172828               main
#                                                   1768365132               main
#                                                   1809099769               main
#                                                   3203306122               main
#                                                   3301681376               main
#                                                   3509461676               main
# {'name': 'comm', 'type': 'function'}              1010172828               comm
#                                                   1768365132               comm
#                                                   1809099769               comm
#                                                   3203306122               comm
#                                                   3301681376               comm
#                                                   3509461676               comm
# {'name': 'comm_large', 'type': 'function'}        1010172828         comm_large
#                                                   1768365132         comm_large
#                                                   1809099769         comm_large
#                                                   3203306122         comm_large
#                                                   3301681376         comm_large
#                                                   3509461676         comm_large
# {'name': 'comm_small', 'type': 'function'}        1010172828         comm_small
#                                                   1768365132         comm_small
#                                                   1809099769         comm_small
#                                                   3203306122         comm_small
#                                                   3301681376         comm_small
#                                                   3509461676         comm_small
# {'name': 'comp', 'type': 'function'}              1010172828               comp
#                                                   1768365132               comp
#                                                   1809099769               comp
#                                                   3203306122               comp
#                                                   3301681376               comp
#                                                   3509461676               comp
# {'name': 'comp_large', 'type': 'function'}        1010172828         comp_large
#                                                   1768365132         comp_large
#                                                   1809099769         comp_large
#                                                   3203306122         comp_large
#                                                   3301681376         comp_large
#                                                   3509461676         comp_large
# {'name': 'correctness_check', 'type': 'function'} 1010172828  correctness_check
#                                                   1768365132  correctness_check
#                                                   1809099769  correctness_check
#                                                   3203306122  correctness_check
#                                                   3301681376  correctness_check
#                                                   3509461676  correctness_check
# {'name': 'data_init', 'type': 'function'}         1010172828          data_init
#                                                   1768365132          data_init
#                                                   1809099769          data_init
#                                                   3203306122          data_init
#                                                   3301681376          data_init
#                                                   3509461676          data_init

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 1010172828           2.11.0-dev
# 1768365132           2.11.0-dev
# 1809099769           2.11.0-dev
# 3203306122           2.11.0-dev
# 3301681376           2.11.0-dev
# 3509461676           2.11.0-dev
#
#                                                  spot.metrics  \
# profile
# 1010172828  min#inclusive#sum#time.duration,max#inclusive#...
# 1768365132  min#inclusive#sum#time.duration,max#inclusive#...
# 1809099769  min#inclusive#sum#time.duration,max#inclusive#...
# 3203306122  min#inclusive#sum#time.duration,max#inclusive#...
# 3301681376  min#inclusive#sum#time.duration,max#inclusive#...
# 3509461676  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 1010172828                                            2
# 1768365132                                            2
# 1809099769                                            2
# 3203306122                                            2
# 3301681376                                            2
# 3509461676                                            2
#
#                        spot.options  spot.channels cali.channel  \
# profile
# 1010172828  cuda.gputime,node.order  regionprofile         spot
# 1768365132  cuda.gputime,node.order  regionprofile         spot
# 1809099769  cuda.gputime,node.order  regionprofile         spot
# 3203306122  cuda.gputime,node.order  regionprofile         spot
# 3301681376  cuda.gputime,node.order  regionprofile         spot
# 3509461676  cuda.gputime,node.order  regionprofile         spot
#
#            spot:cuda.gputime spot:node.order           spot:output  \
# profile
# 1010172828              true            true   t512-v16777216.cali
# 1768365132              true            true    t64-v16777216.cali
# 1809099769              true            true   t256-v16777216.cali
# 3203306122              true            true  t1024-v16777216.cali
# 3301681376              true            true   t128-v16777216.cali
# 3509461676              true            true     t2-v16777216.cali
#
#             launchdate                                          libraries  \
# profile
# 1010172828  1700101294  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1768365132  1700101294  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1809099769  1700101294  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3203306122  1700101294  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3301681376  1700101297  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3509461676  1700101252  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                     cmdline cluster    Algorithm  \
# profile
# 1010172828   [./OddEvenSort, 16777216, 512]       g  OddEvenSort
# 1768365132    [./OddEvenSort, 16777216, 64]       g  OddEvenSort
# 1809099769   [./OddEvenSort, 16777216, 256]       g  OddEvenSort
# 3203306122  [./OddEvenSort, 16777216, 1024]       g  OddEvenSort
# 3301681376   [./OddEvenSort, 16777216, 128]       g  OddEvenSort
# 3509461676     [./OddEvenSort, 16777216, 2]       g  OddEvenSort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize InputType  \
# profile
# 1010172828             CUDA    float               4   16777216    Random
# 1768365132             CUDA    float               4   16777216    Random
# 1809099769             CUDA    float               4   16777216    Random
# 3203306122             CUDA    float               4   16777216    Random
# 3301681376             CUDA    float               4   16777216    Random
# 3509461676             CUDA    float               4   16777216    Random
#
#             num_threads  num_blocks  group_num implementation_source
# profile
# 1010172828          512       32768          1           Handwritten
# 1768365132           64      262144          1           Handwritten
# 1809099769          256       65536          1           Handwritten
# 3203306122         1024       16384          1           Handwritten
# 3301681376          128      131072          1           Handwritten
# 3509461676            2     8388608          1           Handwritten

# %%
#tk.metadata
#tk.statsframe.dataframe["time"] = 1
#print(tk.tree())

# %%
gb = tk.groupby("InputSize")
# Out:
# 1  thickets created...
# {16777216: <thicket.thicket.Thicket object at 0x2abb92a4d730>}

# %%
ctk = th.Thicket.concat_thickets(
    thickets=list(gb.values()),
    headers=list(gb.keys()),
    axis="columns",
    metadata_key="num_threads"
)

# %%
ctk.dataframe
# Out:
#                                                               16777216  \
#                                                                    nid
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              2                  1
#                                                   64                 1
#                                                   128                1
#                                                   256                1
#                                                   512                1
#                                                   1024               1
# {'name': 'comm', 'type': 'function'}              2                  3
#                                                   64                 3
#                                                   128                3
#                                                   256                3
#                                                   512                3
#                                                   1024               3
# {'name': 'comm_large', 'type': 'function'}        2                  4
#                                                   64                 4
#                                                   128                4
#                                                   256                4
#                                                   512                4
#                                                   1024               4
# {'name': 'comm_small', 'type': 'function'}        2                  7
#                                                   64                 7
#                                                   128                7
#                                                   256                7
#                                                   512                7
#                                                   1024               7
# {'name': 'comp', 'type': 'function'}              2                  5
#                                                   64                 5
#                                                   128                5
#                                                   256                5
#                                                   512                5
#                                                   1024               5
# {'name': 'comp_large', 'type': 'function'}        2                  6
#                                                   64                 6
#                                                   128                6
#                                                   256                6
#                                                   512                6
#                                                   1024               6
# {'name': 'correctness_check', 'type': 'function'} 2                  8
#                                                   64                 8
#                                                   128                8
#                                                   256                8
#                                                   512                8
#                                                   1024               8
# {'name': 'data_init', 'type': 'function'}         2                  2
#                                                   64                 2
#                                                   128                2
#                                                   256                2
#                                                   512                2
#                                                   1024               2
#
#                                                                               \
#                                                                 spot.channel
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              2            regionprofile
#                                                   64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm', 'type': 'function'}              2            regionprofile
#                                                   64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm_large', 'type': 'function'}        2            regionprofile
#                                                   64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comm_small', 'type': 'function'}        2            regionprofile
#                                                   64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp', 'type': 'function'}              2            regionprofile
#                                                   64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'comp_large', 'type': 'function'}        2            regionprofile
#                                                   64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'correctness_check', 'type': 'function'} 2            regionprofile
#                                                   64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
# {'name': 'data_init', 'type': 'function'}         2            regionprofile
#                                                   64           regionprofile
#                                                   128          regionprofile
#                                                   256          regionprofile
#                                                   512          regionprofile
#                                                   1024         regionprofile
#
#                                                                              \
#                                                               Min time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              2              753.469657
#                                                   64             638.276183
#                                                   128            628.948160
#                                                   256            767.904157
#                                                   512            754.377841
#                                                   1024           757.546741
# {'name': 'comm', 'type': 'function'}              2              293.277176
#                                                   64             246.638950
#                                                   128            244.251028
#                                                   256            296.408094
#                                                   512            290.523016
#                                                   1024           293.864793
# {'name': 'comm_large', 'type': 'function'}        2                0.014330
#                                                   64               0.015666
#                                                   128              0.014386
#                                                   256              0.015317
#                                                   512              0.014758
#                                                   1024             0.014279
# {'name': 'comm_small', 'type': 'function'}        2              117.730276
#                                                   64              95.325564
#                                                   128             93.988452
#                                                   256            117.623366
#                                                   512            115.014261
#                                                   1024           116.858444
# {'name': 'comp', 'type': 'function'}              2              302.872658
#                                                   64             253.280539
#                                                   128            249.110102
#                                                   256            309.526028
#                                                   512            304.959324
#                                                   1024           304.389826
# {'name': 'comp_large', 'type': 'function'}        2              126.973342
#                                                   64             102.405602
#                                                   128             99.395648
#                                                   256            129.661792
#                                                   512            126.883523
#                                                   1024           127.274094
# {'name': 'correctness_check', 'type': 'function'} 2                0.000044
#                                                   64               0.000042
#                                                   128              0.000045
#                                                   256              0.000044
#                                                   512              0.000044
#                                                   1024             0.000045
# {'name': 'data_init', 'type': 'function'}         2                0.374202
#                                                   64               0.373858
#                                                   128              0.374398
#                                                   256              0.373917
#                                                   512              0.374010
#                                                   1024             0.373936
#
#                                                                              \
#                                                               Max time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              2              753.469657
#                                                   64             638.276183
#                                                   128            628.948160
#                                                   256            767.904157
#                                                   512            754.377841
#                                                   1024           757.546741
# {'name': 'comm', 'type': 'function'}              2              293.277176
#                                                   64             246.638950
#                                                   128            244.251028
#                                                   256            296.408094
#                                                   512            290.523016
#                                                   1024           293.864793
# {'name': 'comm_large', 'type': 'function'}        2                0.014330
#                                                   64               0.015666
#                                                   128              0.014386
#                                                   256              0.015317
#                                                   512              0.014758
#                                                   1024             0.014279
# {'name': 'comm_small', 'type': 'function'}        2              117.730276
#                                                   64              95.325564
#                                                   128             93.988452
#                                                   256            117.623366
#                                                   512            115.014261
#                                                   1024           116.858444
# {'name': 'comp', 'type': 'function'}              2              302.872658
#                                                   64             253.280539
#                                                   128            249.110102
#                                                   256            309.526028
#                                                   512            304.959324
#                                                   1024           304.389826
# {'name': 'comp_large', 'type': 'function'}        2              126.973342
#                                                   64             102.405602
#                                                   128             99.395648
#                                                   256            129.661792
#                                                   512            126.883523
#                                                   1024           127.274094
# {'name': 'correctness_check', 'type': 'function'} 2                0.000044
#                                                   64               0.000042
#                                                   128              0.000045
#                                                   256              0.000044
#                                                   512              0.000044
#                                                   1024             0.000045
# {'name': 'data_init', 'type': 'function'}         2                0.374202
#                                                   64               0.373858
#                                                   128              0.374398
#                                                   256              0.373917
#                                                   512              0.374010
#                                                   1024             0.373936
#
#                                                                              \
#                                                               Avg time/rank
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              2              753.469657
#                                                   64             638.276183
#                                                   128            628.948160
#                                                   256            767.904157
#                                                   512            754.377841
#                                                   1024           757.546741
# {'name': 'comm', 'type': 'function'}              2              293.277176
#                                                   64             246.638950
#                                                   128            244.251028
#                                                   256            296.408094
#                                                   512            290.523016
#                                                   1024           293.864793
# {'name': 'comm_large', 'type': 'function'}        2                0.014330
#                                                   64               0.015666
#                                                   128              0.014386
#                                                   256              0.015317
#                                                   512              0.014758
#                                                   1024             0.014279
# {'name': 'comm_small', 'type': 'function'}        2              117.730276
#                                                   64              95.325564
#                                                   128             93.988452
#                                                   256            117.623366
#                                                   512            115.014261
#                                                   1024           116.858444
# {'name': 'comp', 'type': 'function'}              2              302.872658
#                                                   64             253.280539
#                                                   128            249.110102
#                                                   256            309.526028
#                                                   512            304.959324
#                                                   1024           304.389826
# {'name': 'comp_large', 'type': 'function'}        2              126.973342
#                                                   64             102.405602
#                                                   128             99.395648
#                                                   256            129.661792
#                                                   512            126.883523
#                                                   1024           127.274094
# {'name': 'correctness_check', 'type': 'function'} 2                0.000044
#                                                   64               0.000042
#                                                   128              0.000045
#                                                   256              0.000044
#                                                   512              0.000044
#                                                   1024             0.000045
# {'name': 'data_init', 'type': 'function'}         2                0.374202
#                                                   64               0.373858
#                                                   128              0.374398
#                                                   256              0.373917
#                                                   512              0.374010
#                                                   1024             0.373936
#
#                                                                            \
#                                                                Total time
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              2            753.469657
#                                                   64           638.276183
#                                                   128          628.948160
#                                                   256          767.904157
#                                                   512          754.377841
#                                                   1024         757.546741
# {'name': 'comm', 'type': 'function'}              2            293.277176
#                                                   64           246.638950
#                                                   128          244.251028
#                                                   256          296.408094
#                                                   512          290.523016
#                                                   1024         293.864793
# {'name': 'comm_large', 'type': 'function'}        2              0.014330
#                                                   64             0.015666
#                                                   128            0.014386
#                                                   256            0.015317
#                                                   512            0.014758
#                                                   1024           0.014279
# {'name': 'comm_small', 'type': 'function'}        2            117.730276
#                                                   64            95.325564
#                                                   128           93.988452
#                                                   256          117.623366
#                                                   512          115.014261
#                                                   1024         116.858444
# {'name': 'comp', 'type': 'function'}              2            302.872658
#                                                   64           253.280539
#                                                   128          249.110102
#                                                   256          309.526028
#                                                   512          304.959324
#                                                   1024         304.389826
# {'name': 'comp_large', 'type': 'function'}        2            126.973342
#                                                   64           102.405602
#                                                   128           99.395648
#                                                   256          129.661792
#                                                   512          126.883523
#                                                   1024         127.274094
# {'name': 'correctness_check', 'type': 'function'} 2              0.000044
#                                                   64             0.000042
#                                                   128            0.000045
#                                                   256            0.000044
#                                                   512            0.000044
#                                                   1024           0.000045
# {'name': 'data_init', 'type': 'function'}         2              0.374202
#                                                   64             0.373858
#                                                   128            0.374398
#                                                   256            0.373917
#                                                   512            0.374010
#                                                   1024           0.373936
#
#                                                                             name
#
# node                                              num_threads
# {'name': 'main', 'type': 'function'}              2                         main
#                                                   64                        main
#                                                   128                       main
#                                                   256                       main
#                                                   512                       main
#                                                   1024                      main
# {'name': 'comm', 'type': 'function'}              2                         comm
#                                                   64                        comm
#                                                   128                       comm
#                                                   256                       comm
#                                                   512                       comm
#                                                   1024                      comm
# {'name': 'comm_large', 'type': 'function'}        2                   comm_large
#                                                   64                  comm_large
#                                                   128                 comm_large
#                                                   256                 comm_large
#                                                   512                 comm_large
#                                                   1024                comm_large
# {'name': 'comm_small', 'type': 'function'}        2                   comm_small
#                                                   64                  comm_small
#                                                   128                 comm_small
#                                                   256                 comm_small
#                                                   512                 comm_small
#                                                   1024                comm_small
# {'name': 'comp', 'type': 'function'}              2                         comp
#                                                   64                        comp
#                                                   128                       comp
#                                                   256                       comp
#                                                   512                       comp
#                                                   1024                      comp
# {'name': 'comp_large', 'type': 'function'}        2                   comp_large
#                                                   64                  comp_large
#                                                   128                 comp_large
#                                                   256                 comp_large
#                                                   512                 comp_large
#                                                   1024                comp_large
# {'name': 'correctness_check', 'type': 'function'} 2            correctness_check
#                                                   64           correctness_check
#                                                   128          correctness_check
#                                                   256          correctness_check
#                                                   512          correctness_check
#                                                   1024         correctness_check
# {'name': 'data_init', 'type': 'function'}         2                    data_init
#                                                   64                   data_init
#                                                   128                  data_init
#                                                   256                  data_init
#                                                   512                  data_init
#                                                   1024                 data_init

# %%
# Drop unwanted columns
ctk.dataframe = ctk.dataframe.reset_index().drop([("node", ""), (16777216, "nid")], axis=1)
# Rename index to remove tuple
# Strong Scaling
ctk.dataframe = ctk.dataframe.drop([(16777216, 'Min time/rank'),(16777216, 'Max time/rank'),(16777216, 'Avg time/rank') ], axis=1)

# # Weak Scaling
# ctk.dataframe = ctk.dataframe.drop([(67108864, 'Min time/rank'),(67108864, 'Max time/rank'),(67108864, 'Avg time/rank'), (67108864, "nid"), (67108864, "Total time")  ], axis=1)
# ctk.dataframe = ctk.dataframe.drop([(262144, 'Min time/rank'),(262144, 'Max time/rank'),(262144, 'Avg time/rank'), (262144, "nid"), (262144, "Total time") ], axis=1)
# ctk.dataframe = ctk.dataframe.drop([(1048576, 'Min time/rank'),(1048576, 'Max time/rank'),(1048576, 'Avg time/rank'), (1048576, "nid"), (1048576, "Total time")], axis=1)
# ctk.dataframe = ctk.dataframe.drop([(4194304, 'Min time/rank'),(4194304, 'Max time/rank'),(4194304, 'Avg time/rank'), (4194304, "nid"), (4194304, "Total time")], axis=1)
# ctk.dataframe = ctk.dataframe.drop([(16777216, 'Min time/rank'),(16777216, 'Max time/rank'),(16777216, 'Avg time/rank'), (16777216, "Total time") ], axis=1)

# ctk.dataframe = ctk.dataframe.drop([(67108864, 'Min GPU time/rank'),(67108864, 'Max GPU time/rank'),(67108864, 'Avg GPU time/rank') ], axis=1)
# ctk.dataframe = ctk.dataframe.drop([(262144, 'Min GPU time/rank'),(262144, 'Max GPU time/rank'),(262144, 'Avg GPU time/rank') ], axis=1)
# ctk.dataframe = ctk.dataframe.drop([(1048576, 'Min GPU time/rank'),(1048576, 'Max GPU time/rank'),(1048576, 'Avg GPU time/rank')], axis=1)
# ctk.dataframe = ctk.dataframe.drop([(4194304, 'Min GPU time/rank'),(4194304, 'Max GPU time/rank'),(4194304, 'Avg GPU time/rank')], axis=1)
# ctk.dataframe = ctk.dataframe.drop([(16777216, 'Min GPU time/rank'),(16777216, 'Max GPU time/rank'),(16777216, 'Avg GPU time/rank') ], axis=1)

#print(ctk.dataframe.columns)
ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])
# Drop "time" label as it is redundant
#ctk.dataframe.columns = ctk.dataframe.columns.droplevel(1)

# %% [raw]
# ctk.dataframe

# %%
# Define common variables
function_names = set(ctk.dataframe.index.get_level_values("name"))
procs = sorted(list(set(ctk.dataframe.index.get_level_values("num_threads"))))
matrix_sizes = sorted(ctk.dataframe.columns.tolist())
#time = set(ctk.dataframe.index.get_level_values("Total time"))

# %%
def plot_mpl(df, title, xlabel, ylabel):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(
        df,
        marker='o',
    )
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.legend(matrix_sizes)
    plt.grid(True)
    plt.yscale("log", base=2)
    plt.xscale("log", base=2)
    plt.xticks(threads)
    plt.show()
    return fig, ax

# %%
ctk.dataframe.loc["main"]
# Out:
#                   16777216
#               spot.channel  Total time
# num_threads
# 2            regionprofile  753.469657
# 64           regionprofile  638.276183
# 128          regionprofile  628.948160
# 256          regionprofile  767.904157
# 512          regionprofile  754.377841
# 1024         regionprofile  757.546741

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %%
for name in function_names:
    plot_pandas(
        df=ctk.dataframe.loc[name],
        title=name,
        xlabel="Number of Threads",
        ylabel="Time (seconds)",
        loglog=True
    )
